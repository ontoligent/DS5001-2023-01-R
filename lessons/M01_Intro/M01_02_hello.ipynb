# %% [markdown]
# # Metadata
#
# ```
# Course:   DS 5001
# Module:   01 Lab
# Topic:    Hello, World!
# Author:   R.C. Alvarado
# Purpose:  First notebook
# ```

# %% [markdown]
# # Start Here

# %% [markdown]
# ## Values and Variables

# %%
"Hello, World!"
# Out:
# 'Hello, World!'

# %%
x = "Hello, World!"

# %%
x
# Out:
# 'Hello, World!'

# %% [markdown]
# ## `print()`

# %%
print(x)
# Out:
# Hello, World!

# %%
print("Hello Raf!")
# Out:
# Hello Raf!

# %%
print("Hello Quetzil!")
# Out:
# Hello Quetzil!

# %% [markdown]
# ## Functions

# %%
def hello(fname=''):
    print("Hello {}!".format(fname))

# %%
hello("Raf")
# Out:
# Hello Raf!

# %%
hello("Quetzil!")
# Out:
# Hello Quetzil!!

# %% [markdown]
# # Style
