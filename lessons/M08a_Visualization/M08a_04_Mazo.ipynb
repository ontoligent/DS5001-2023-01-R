# %% [markdown]
# # Metadata
#
# ```yaml
# Course:   DS 5001
# Module:   08a Lab
# Topic:    Using Mazo
# Author:   R.C. Alvarado
# Date:     23 March 2023
# ```
#
# **Purpose:** Demonstrate utility of Mazo output.

# %% [markdown]
# # Synopsis
#
# 1. Download and install mazo https://github.com/ontoligent-design/mazo
# 2. Set up your project directory and put in appropriate files and diretories
# 3. Run mazo to generate topic models

# %% [markdown]
# # Set Up

# %% [markdown]
# ## Config

# %%
# !ls -l output/
# Out:
# total 0
# drwxr-xr-x@ 12 rca2t1  staff  384 Mar 23 13:44 demo-20-16795933002483132
# drwxr-xr-x@ 12 rca2t1  staff  384 Mar 23 13:32 novels-20-16795927188712971

# %%
model_id = 'novels-20-16795927188712971'

# %%
mazo_tables = f"./output/{model_id}/tables/*.*"
db_file = f"./{model_id}.db"

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
from glob import glob
import sqlite3

# %% [markdown]
# # Import Model Tables

# %%
class Model: pass
model = Model()

# %%
db = sqlite3.connect(db_file)

# %%
for tfile in glob(mazo_tables):
    tname = tfile.split('/')[-1].split('.')[0]
    print(tname)
    df = pd.read_csv(tfile)
    df.to_sql(tname, db)
    setattr(model, tname, df)
# Out:
# TOPIC
# TOPICWORD_DIAGS
# TOPICPHRASE
# DOCTOPIC_NARROW
# VOCAB
# DOCTOPIC
# TOPICWORD
# PHRASE
# TOPICWORD_NARROW
# DOCWORD
# DOC

# %%
model.TOPICWORD_NARROW
# Out:
#        word_id  topic_id  word_count
# 0            0         7          11
# 1            1         8         178
# 2            1         7          37
# 3            2         8         599
# 4            2         7         272
# ...        ...       ...         ...
# 60543    26792         6           1
# 60544    26793         1           1
# 60545    26794         1           1
# 60546    26795         1           1
# 60547    26796         6           1
#
# [60548 rows x 3 columns]

# %%
model.DOCTOPIC.set_index('doc_id')
# Out:
#                0         1         2         3         4         5         6  \
# doc_id
# 0       0.022766  0.009205  0.002741  0.003566  0.010347  0.146695  0.053455
# 1       0.000038  0.004022  0.000005  0.000006  0.000017  0.332799  0.222794
# 2       0.000679  0.000015  0.005783  0.000006  0.000017  0.380332  0.118224
# 3       0.001789  0.016114  0.000006  0.000008  0.000022  0.447470  0.095375
# 4       0.008816  0.022592  0.000004  0.000006  0.000016  0.372447  0.040222
# ...          ...       ...       ...       ...       ...       ...       ...
# 316     0.000054  0.000022  0.000006  0.036312  0.377205  0.014961  0.002955
# 317     0.025550  0.003214  0.000009  0.000011  0.268823  0.003015  0.001444
# 318     0.306330  0.000044  0.000013  0.000017  0.244069  0.002615  0.000256
# 319     0.283570  0.000111  0.000033  0.000043  0.256785  0.035674  0.005489
# 320     0.049885  0.288852  0.000005  0.000006  0.011967  0.000592  0.053352
#
# ...

# %%
model.TOPICWORD.set_index('word_id')
# Out:
#                 0         1         2         3         4         5         6  \
# word_id
# 0        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3        0.000263  0.000000  0.000635  0.002932  0.000000  0.003044  0.002646
# 4        0.000394  0.000357  0.000000  0.000000  0.000654  0.000000  0.000226
# ...           ...       ...       ...       ...       ...       ...       ...
# 26792    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000032
# 26793    0.000000  0.000089  0.000000  0.000000  0.000000  0.000000  0.000000
# 26794    0.000000  0.000089  0.000000  0.000000  0.000000  0.000000  0.000000
# 26795    0.000000  0.000089  0.000000  0.000000  0.000000  0.000000  0.000000
# 26796    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000032
#
# ...
