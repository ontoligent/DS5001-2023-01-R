# %% [markdown]
# # Metadata
#
# ```yaml
# Course:   DS 5001
# Module:   92 Helper Notebooks
# Topic:    Using MALLET
# ```

# %% [markdown]
# # Notes
#
# See Appendix below information on how download and install <a href="https://mimno.github.io/Mallet/topics">MALLET</a>.

# %% [markdown]
# # Set Up

# %%
data_home = "../data"
local_lib = "../lib"
data_prefix = 'novels'
OHCO = ['book_id','chap_id','para_num','sent_num','token_num']

# %%
max_words = 10000

# For MALLET
num_topics = 20
num_iters = 1000
show_interval = 100

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Import CORPUS

# %%
LIB = pd.read_csv(f"{data_home}/{data_prefix}/{data_prefix}-LIB.csv").set_index(OHCO[:1])

# %%
CORPUS = pd.read_csv(f"{data_home}/{data_prefix}/{data_prefix}-CORPUS.csv").set_index(OHCO)

# %%
CORPUS.head()
# Out:
#                                                      pos     term_str
# book_id         chap_id para_num sent_num token_num
# secretadversary 1       0        1        0           DT          the
#                                           1          NNP        young
#                                           2          NNP  adventurers
#                                           3          NNP          ltd
#                         1        0        0           JJ        tommy

# %% [markdown]
# # Create DOC

# %%
def gather_docs(CORPUS, ohco_level, term_col='term_str'):
    OHCO = CORPUS.index.names
    CORPUS[term_col] = CORPUS[term_col].astype('str')
    DOC = CORPUS.groupby(OHCO[:ohco_level])[term_col].apply(lambda x:' '.join(x)).to_frame('doc_str')
    return DOC

# %%
DOC = gather_docs(CORPUS, 2)

# %%
DOC['n_tokens'] = DOC.doc_str.apply(lambda x: len(x.split()))

# %%
DOC
# Out:
#                                                               doc_str  \
# book_id    chap_id
# adventures 1        a scandal in bohemia i to sherlock holmes she ...
#            2        the red headed league i had called upon my fri...
#            3        a case of identity my dear fellow said sherloc...
#            4        the boscombe valley mystery we were seated at ...
#            5        the five orange pips when i glance over my not...
# ...                                                               ...
# udolpho    54       vi unnatural deeds do breed unnatural troubles...
#            55       vii but in these cases we still have judgment ...
#            56       viii then fresh tears stood on her cheek as do...
#            57       ix now my task is smoothly done i can fly or i...
# usher      1        fall of the house of usher son coeur est un lu...
#
#                     n_tokens
# book_id    chap_id
# adventures 1            8608
#            2            9197
#            3            7020
#            4            9685
#            5            7365
# ...                      ...
# udolpho    54           5605
#            55           4164
#            56           2522
#            57            977
# usher      1            7212
#
# [320 rows x 2 columns]

# %% [markdown]
# ## Dump corpus to CSV file

# %%
mallet_corpus = DOC.join(LIB)[['doc_str','author_id']]
mallet_corpus.columns = 'doc_content doc_label'.split()
mallet_corpus[['doc_label','doc_content']].to_csv('novels-corpus.csv', index=False)

# %% [markdown]
# ## MALLET Time

# %% [markdown]
# ### Show MALLET options

# %%
mallet_home = "/Users/rca2t1/opt/mallet/bin"

# %%
! {mallet_home}/mallet
# Out:
# Unrecognized command:
# Mallet 2.0 commands:
#
#   import-dir         load the contents of a directory into mallet instances (one per file)
#   import-file        load a single file into mallet instances (one per line)
#   import-svmlight    load SVMLight format data files into Mallet instances
#   info               get information about Mallet instances
#   train-classifier   train a classifier from Mallet data files
#   classify-dir       classify data from a single file with a saved classifier
#   classify-file      classify the contents of a directory with a saved classifier
#   classify-svmlight  classify data from a single file in SVMLight format
#   train-topics       train a topic model from Mallet data files
#   infer-topics       use a trained topic model to infer topics for new documents
#   evaluate-topics    estimate the probability of new documents under a trained model
#   prune              remove features based on frequency or information gain
#   split              divide data into testing, training, and validation portions
#   bulk-load          for big input files, efficiently prune vocabulary and import docs
#
# Include --help with any option for more information

# %% [markdown]
# ### Import corpus

# %%
# !{mallet_home}/mallet import-file --input novels-corpus.csv --output novels-corpus.mallet --keep-sequence TRUE

# %% [markdown]
# ### Train topics

# %%
# !{mallet_home}/mallet train-topics --input novels-corpus.mallet --num-topics {num_topics} --num-iterations {num_iters} \
--output-doc-topics novels-doc-topics.txt \
--output-topic-keys novels-topic-keys.txt \
--word-topic-counts-file novels-word-topic-counts-file.txt \
--topic-word-weights-file novels-topic-word-weights-file.txt \
--xml-topic-report novels-topic-report.xml \
--xml-topic-phrase-report novels-topic-phrase-report.xml \
--show-topics-interval {show_interval} \
--use-symmetric-alpha false  \
--optimize-interval 100 \
--diagnostics-file novels-diagnostics.xml
# Out:
# Mallet LDA: 20 topics, 5 topic bits, 11111 topic mask
# Data loaded.
# max tokens: 15717
# total tokens: 1164070
# <10> LL/token: -9.08241
# <20> LL/token: -8.58981
# <30> LL/token: -8.40238
# <40> LL/token: -8.30464
# <50> LL/token: -8.24356
# <60> LL/token: -8.1964
# <70> LL/token: -8.15861
# <80> LL/token: -8.1218
# <90> LL/token: -8.09719
#
# 0	0.25	the that have which upon was holmes this but had from not there been has his then man sir with
# 1	0.25	and that you his him the will have with are all for can this may our when has your said
# 2	0.25	not the and very was but for catherine they have you would could isabella their such only miss were dear
# 3	0.25	the and was his had with were out down there they said through night its came light great could one
# 4	0.25	the had and was that which with have sergeant franklin miss house rachel this diamond from betteredge time when back
# 5	0.25	the and been which this was that its were all from part had having without their these even some far
# 6	0.25	the emily she and that his her was had for montoni said valancourt now with they him count annette but
# 7	0.25	his him the was that himself were and for them most with then from hand means man into make every
# 8	0.25	and which with the had upon that from was more for when heart but now eyes yet every thus only
# 9	0.25	and the for that with was had been only some there one might would when were over such about two
# 10	0.25	the was that not poirot had but inglethorp mrs have john will been what yes cavendish did room one are
# 11	0.25	the was tuppence tommy but with julius she sir his girl then james and that they had jane him her
# 12	0.25	the your his with this matilda you from not and manfred thou upon agnes antonia for thy ambrosio lorenzo project
# 13	0.25	you have that not and but your will this what would said are who when the should can was for
# 14	0.25	the was but not for had who with heard door found were our would these this one that and myself
# 15	0.25	the and they their was with were them that but had among from all into these life many like which
# 16	0.25	you said what and that about out know for well your was dont the very little they say but did
# 17	0.25	her she and had was with the that herself for all might before could been than lady time such from
# 18	0.25	the and his said lord him you sir will with that they for your edmund all baron them upon this
# 19	0.25	the and not was but for that all then there have when could room from them went night must over
#
# <100> LL/token: -8.07791
# <110> LL/token: -8.06188
# <120> LL/token: -8.04078
# <130> LL/token: -8.02445
# <140> LL/token: -8.01317
# <150> LL/token: -8.00051
# <160> LL/token: -7.99143
# <170> LL/token: -7.98261
# <180> LL/token: -7.9764
# <190> LL/token: -7.97228
#
# 0	0.25	the that which upon have holmes had his from this but not then there been has with sir very man
# 1	0.25	and that him his have you the will are with can has all when for our this may must one
# 2	0.25	the not and catherine very for they but could miss was have such were tilney mrs would their only brother
# 3	0.25	the and was his with there had were through door they down room out into but night which its could
# 4	0.25	the had and which sergeant franklin miss was with that rachel house have diamond betteredge when room time for this
# 5	0.25	the been this that which not and its from have these was their all with one were any part having
# 6	0.25	the and emily that his was she had montoni said for they valancourt who this then with but him count
# 7	0.25	his the him was and that were with them himself their most then from had other who into while being
# 8	0.25	and the which with had upon that for more when from was heart eyes now every still did after towards
# 9	0.25	and was the for had been would with one but that found two were only when there who some little
# 10	0.25	the that was poirot not inglethorp mrs had but john have will cavendish yes did room then been cynthia lawrence
# 11	0.25	the tuppence tommy but julius sir james then with jane girl they vandemeyer dont mrs brown ive she over youre
# 12	0.25	the your this with matilda not manfred his for from antonia you thou agnes ambrosio lorenzo thy theodore project gutenberg
# 13	0.25	you not but have that your will and what this would said are for shall can the may should then
# 14	0.25	the was but had not that for they this one from heard would door our who myself first some death
# 15	0.25	the and they their with were that which was them but from these all among sun sea day where some
# 16	0.25	you that was said what for not the out about know and well they all would but did say have
# 17	0.25	her she and had was with all the herself for been might could than from that before room which without
# 18	0.25	the and his said lord him sir they will with edmund for you that baron your them all philip their
# 19	0.25	the and not that for but all was then some could van when time helsing there more now had went
#
# <200> LL/token: -7.96899
# <210> LL/token: -7.96129
# <220> LL/token: -7.95449
# <230> LL/token: -7.95111
# <240> LL/token: -7.94658
# <250> LL/token: -7.94521
# <260> LL/token: -7.94168
# <270> LL/token: -7.93486
# <280> LL/token: -7.93462
# <290> LL/token: -7.93078
#
# 0	0.25	the which that upon holmes have his had from very but with this sir then not man our should has
# 1	0.25	and that him his have the for this are will with can has all you must our when may from
# 2	0.25	the and not catherine very for they but was could miss their were would mrs tilney such with only being
# 3	0.25	the and was were his with there had door room they through out down into upon night but light hand
# 4	0.25	the and had which sergeant franklin that miss house rachel diamond with betteredge when room from this time your lady
# 5	0.25	the that which have this not been its from all with these any now what more than without thus having
# 6	0.25	the and emily that was had his for montoni said with this she who they valancourt him then count but
# 7	0.25	his the was and him that with for were had their them himself then from made most who man while
# 8	0.25	and which the with upon had was when that more from heart now those before eyes yet every still even
# 9	0.25	and the was had would for been one but that were there found two when only some could might until
# 10	0.25	the that poirot not inglethorp mrs was but john had yes cavendish did she will cynthia room been lawrence howard
# 11	0.25	the tuppence tommy but julius sir james she they thats jane girl then dont vandemeyer mrs young ive over brown
# 12	0.25	the your with this and matilda not manfred from antonia his thou you agnes said ambrosio lorenzo thy theodore project
# 13	0.25	you not but have your that will and what this would are shall said may for can who then has
# 14	0.25	the was but that not for this they from had heard death found door one should some myself would could
# 15	0.25	the and they their with but were these from its that all sun one sea where over this father day
# 16	0.25	you was said that what not out the have about for and know there with well all but little had
# 17	0.25	her she and had was been with all herself the from for might without room than which though that moment
# 18	0.25	the and his lord said him sir you they edmund will with your all baron for that them philip their
# 19	0.25	the and not for that all but then when which was van helsing there them over some lucy time have
#
# [beta: 0.01758]
# <300> LL/token: -7.92414
# <310> LL/token: -7.9283
# <320> LL/token: -7.92999
# <330> LL/token: -7.92987
# <340> LL/token: -7.92802
# <350> LL/token: -7.92364
# <360> LL/token: -7.9191
# <370> LL/token: -7.91821
# <380> LL/token: -7.91144
# <390> LL/token: -7.91001
#
# 0	0.17832	the which that upon holmes his have sir from had not our very then this man but should your watson
# 1	0.35057	and that the have him for with his all are will this can from when has our you may more
# 2	0.19081	the and not catherine they very for could miss but mrs tilney was were such their general much only with
# 3	0.31227	the and was his with were had there door room they which down through into then but night out light
# 4	0.17065	the had which and sergeant franklin miss rachel house diamond betteredge when room this time that your own lady blake
# 5	0.33092	the have not which that this upon been its from all with these what than there any now body into
# 6	0.16374	the and emily that was his had said montoni for this with they now him valancourt who not but from
# 7	0.36194	the his was him and with that were their them himself had from for they made while most who into
# 8	0.31942	and which the with upon had that was when from more heart every for now yet eyes its those before
# 9	0.32452	the and was had that been but one would were for found some could who when very might man there
# 10	0.12165	the poirot that inglethorp not mrs was john she had yes cavendish but did will cynthia sir lawrence howard room
# 11	0.1364	the tuppence tommy julius but sir james jane thats girl vandemeyer mrs dont they got brown then guess carter young
# 12	0.11823	the this not matilda your with manfred antonia thou agnes ambrosio lorenzo thy said and theodore his you project isabella
# 13	0.34398	you not but that have your will and this what would are for should shall said then may know can
# 14	0.32025	the was but that not this for had from heard they some one myself now first who would moment door
# 15	0.27174	the and they their with but this which were from them among its these mountains sun been sea all where
# 16	0.33439	you was that the said what not and out about have know there for but well did had very little
# 17	0.33885	her she and had was been with all for the herself from which might more when some than without left
# 18	0.17168	the and his lord said sir him edmund they will baron your you with them philip for all upon son
# 19	0.19073	the and not that but all for when van then helsing was lucy over there could some them which mina
#
# [beta: 0.02065]
# <400> LL/token: -7.90725
# <410> LL/token: -7.91117
# <420> LL/token: -7.90716
# <430> LL/token: -7.90487
# <440> LL/token: -7.90715
# <450> LL/token: -7.90763
# <460> LL/token: -7.90644
# <470> LL/token: -7.9089
# <480> LL/token: -7.91251
# <490> LL/token: -7.91133
#
# 0	0.12938	the upon which holmes have that his sir our from then not very this over has your had should watson
# 1	0.44064	and the that him have his for with all are will this from can when more has may our you
# 2	0.14395	and not catherine the very they for miss mrs tilney could such were their but them much general only any
# 3	0.35303	the and was his with were had door room there but they down its through into night out saw their
# 4	0.11972	the had which sergeant franklin and miss rachel house diamond this betteredge time room lady own back when have your
# 5	0.31418	the have this not that upon which its been with from all there body are such than these any thus
# 6	0.12254	the and that emily had which was his for montoni this with said but now who they valancourt from count
# 7	0.4482	the his and him was with that had their were them himself they for from who than while such most
# 8	0.36036	and the which with was that had upon for when from more heart yet those eyes every its mind these
# 9	0.37266	the and was had that been but which one for would were some could man found might there two who
# 10	0.06699	the poirot inglethorp mrs not that john but yes cavendish she will cynthia did sir lawrence howard room been dorcas
# 11	0.0855	the tuppence tommy julius sir but james mrs jane dont thats they girl vandemeyer its know get brown ive then
# 12	0.05986	the your matilda this with manfred antonia his not thou agnes said ambrosio lorenzo theodore thy isabella you project gutenberg
# 13	0.41102	you not but have that your will what this and would said are shall for then should know own can
# 14	0.3575	the was but that upon not which from this had heard for one were now some still would then who
# 15	0.26364	the and they with their were this them from its over among mountains sun sea all little some but road
# 16	0.41195	you the was that said what not and out there for had about with have but did well little would
# 17	0.40712	her she the and was had with all been from herself for more when could might without than left over
# 18	0.12437	the and his lord said sir edmund him they baron will your for philip with them all you that son
# 19	0.13463	the and not for but that all then van when helsing there which some lucy them was went mina must
#
# [beta: 0.02182]
# <500> LL/token: -7.91089
# <510> LL/token: -7.90554
# <520> LL/token: -7.90163
# <530> LL/token: -7.9058
# <540> LL/token: -7.90353
# <550> LL/token: -7.90198
# <560> LL/token: -7.8988
# <570> LL/token: -7.89948
# <580> LL/token: -7.9
# <590> LL/token: -7.89843
#
# 0	0.09563	upon holmes which his have you that sir our very from then not over your has watson had sherlock should
# 1	0.52437	and the that him have his all with are for from will when this can more has now may one
# 2	0.10701	not catherine and very they for mrs tilney miss their could were but such only much general isabella being would
# 3	0.38451	the and was his with had were there door they room but down could its through night out which their
# 4	0.09457	the had which sergeant franklin miss rachel diamond betteredge house this room when time own lady your blake back cuff
# 5	0.21835	the have not that upon this from its with which been all now these there thus body are very than
# 6	0.10088	the and that emily was had which his said this for montoni with now who but valancourt they from count
# 7	0.50976	the his and was with him that their for them they himself were had made from who than most upon
# 8	0.38612	and which the had with that from when was heart its yet these those life before mind more felt every
# 9	0.41146	the was and had that been which for one but this would were some could who man there found might
# 10	0.03993	poirot inglethorp not mrs john yes was that the cavendish had she but cynthia will sir lawrence howard room did
# 11	0.06236	tuppence tommy julius the sir but james jane mrs thats they dont vandemeyer girl its get brown carter ive guess
# 12	0.03892	the matilda said your with manfred this not antonia thou agnes ambrosio lorenzo thy theodore isabella project gutenberg his from
# 13	0.45709	you not but have your that will this what would for are shall should must know may can has then
# 14	0.36818	the was that which upon this but from not for had some heard were then still one would into moment
# 15	0.24179	the and they with their from were over among them but mountains little sun sea road light some this along
# 16	0.4802	you the was that said what not out for have and there but about had did know with little well
# 17	0.45631	her she and the had was with all for been herself from more could might when than over room without
# 18	0.09138	the and his lord said sir edmund they baron will him you philip for all your them upon with son
# 19	0.09698	and not for the but all then van helsing which lucy some them must when mina was jonathan our that
#
# [beta: 0.02224]
# <600> LL/token: -7.89655
# <610> LL/token: -7.89569
# <620> LL/token: -7.89783
# <630> LL/token: -7.89353
# <640> LL/token: -7.8933
# <650> LL/token: -7.8921
# <660> LL/token: -7.89287
# <670> LL/token: -7.89302
# <680> LL/token: -7.89082
# <690> LL/token: -7.88983
#
# 0	0.0776	his upon which holmes you have sir very our from man that then had not has your watson should sherlock
# 1	0.60433	and the that him have for with are his all when will this from now can has more may see
# 2	0.08776	not catherine and very they mrs miss could tilney for but their such general only isabella morland would thorpe any
# 3	0.40332	the and was his with had were but there door they room not out down could through its into night
# 4	0.07748	the had which sergeant franklin miss rachel diamond house betteredge room back own have lady again blake cuff your godfrey
# 5	0.15144	the have not upon that this its from which been all are but there body what thus than corpse such
# 6	0.08909	the and that emily had which was said this but montoni for now his who valancourt from when not then
# 7	0.55317	his the and with was him that their them they for himself had were from time made while upon more
# 8	0.39039	and which the that with had when was from life its these yet heart all eyes mind before could for
# 9	0.44763	the was had and that been which one this for would but were some man found could there house two
# 10	0.02909	poirot inglethorp not mrs john that yes but was cavendish will she cynthia room lawrence did howard sir had dorcas
# 11	0.05075	tuppence tommy julius the but sir james mrs jane his they thats girl vandemeyer dont get guess brown carter him
# 12	0.02717	the matilda said this manfred your antonia thou ambrosio lorenzo agnes with not thy theodore his isabella project gutenberg castle
# 13	0.49002	you not but have your will that what this would for shall are which may should know own must can
# 14	0.36942	the which was upon but from that this had not for now one then would some heard into still were
# 15	0.22391	the and with they their were from aubert which mountains its them over among woods light little where along into
# 16	0.53204	you the was said what not that out about but have there know did had for little would very well
# 17	0.49559	her she the and was had with for all herself from more been could might than into when moment before
# 18	0.07361	the and his said lord sir edmund they baron him will philip your you them all oswald upon lovel son
# 19	0.07468	not and the but all for his then van which helsing when lucy some time was mina our night them
#
# [beta: 0.02272]
# <700> LL/token: -7.88927
# <710> LL/token: -7.89007
# <720> LL/token: -7.88932
# <730> LL/token: -7.88647
# <740> LL/token: -7.88289
# <750> LL/token: -7.88308
# <760> LL/token: -7.88304
# <770> LL/token: -7.87864
# <780> LL/token: -7.88154
# <790> LL/token: -7.87896
#
# 0	0.06735	upon holmes his which have you sir very our not then man your has from but watson should sherlock case
# 1	0.67697	and the that for him have his with all are when from will this now more can see has must
# 2	0.07584	not catherine and very they but miss mrs tilney could such for their were much general isabella thorpe morland any
# 3	0.41426	the and was had with his were but door there they could room which out its down through into them
# 4	0.06819	the had which sergeant franklin miss rachel diamond betteredge house room when your time lady have own again blake cuff
# 5	0.11078	the have not upon been its from this which all with body that very thus than what has marie corpse
# 6	0.08408	the and that emily had which was said this montoni but not now who for valancourt then when his they
# 7	0.58616	his the and with was him that their had for they from them himself were made than who more other
# 8	0.37979	and the which with had was when that from not its yet heart for these life more felt before could
# 9	0.47381	the was that had and which been this but one would were some for who there house could man found
# 10	0.02283	poirot inglethorp mrs not john yes that cavendish but did she been will cynthia room was lawrence howard had sir
# 11	0.04547	tuppence tommy the julius but sir james jane they thats mrs girl vandemeyer dont then got his guess ive get
# 12	0.02415	the said matilda manfred antonia this thou not ambrosio thy theodore isabella project gutenberg your with castle any cried hippolita
# 13	0.50738	you not but have your that will what this would shall are should may know which for can must think
# 14	0.3614	the upon which was but this that then not from were now still your into every agnes some would length
# 15	0.21806	the and they with which their from aubert were over mountains among them woods its into while along where whose
# 16	0.56638	you was the said what not that out about there have had know would little but very did say one
# 17	0.53018	her she the and had was for with from all herself could been more before when might moment heart without
# 18	0.06183	the and lord said his sir edmund they baron him philip will your them upon for you all oswald son
# 19	0.06578	not and but all then van helsing which his lucy when some mina shall was them must may night went
#
# [beta: 0.02301]
# <800> LL/token: -7.87645
# <810> LL/token: -7.87068
# <820> LL/token: -7.86946
# <830> LL/token: -7.87168
# <840> LL/token: -7.86686
# <850> LL/token: -7.86162
# <860> LL/token: -7.86191
# <870> LL/token: -7.85886
# <880> LL/token: -7.85538
# <890> LL/token: -7.8542
#
# 0	0.06472	upon his holmes which have you sir but very our man your has should then watson sherlock case could that
# 1	0.75143	and the that for with him have his all are when this will now there from more can has must
# 2	0.06703	not catherine and but very they miss mrs tilney for could such their general much isabella morland thorpe were being
# 3	0.42667	the and was his had were with but door they there could upon down through into room which one out
# 4	0.06291	the had sergeant which franklin miss rachel diamond room betteredge time own house back this lady when again blake your
# 5	0.08498	the have upon not but its this which very with been are corpse body marie about there than has all
# 6	0.08329	the that and emily which but had was this not said montoni now from for she who valancourt then would
# 7	0.60629	his and the was with him that for their they them had himself who were such more than from other
# 8	0.36367	and the but had which was that when with not for its heart were from yet father myself life mind
# 9	0.50114	the was that had been which this and from one would some for were not who found could into time
# 10	0.02386	poirot inglethorp mrs not that but john yes cavendish she was room will cynthia lawrence howard did sir dorcas alfred
# 11	0.04232	tuppence tommy the julius sir but james jane mrs girl vandemeyer dont thats his its her get she carter ive
# 12	0.02346	the said manfred thou not this isabella thy project gutenberg matilda lord but theodore thee from hippolita princess prince your
# 13	0.51496	you not your have but will that what this would said shall are should which know may own must can
# 14	0.34082	the which upon from this but not that your was agnes antonia then every ambrosio lorenzo now with still bosom
# 15	0.21408	the and they with which their aubert from were its them some mountains among woods over light along little where
# 16	0.59552	you was the said what that not but out about had have very there know would did your with little
# 17	0.55902	her she the and was had with for could all herself been when from before might which more into time
# 18	0.0526	the and lord said sir his edmund baron will you they but him philip your upon them oswald for lovel
# 19	0.05956	not but and all van his helsing then for lucy them which our when mina some could may went time
#
# [beta: 0.02363]
# <900> LL/token: -7.85641
# <910> LL/token: -7.85192
# <920> LL/token: -7.85123
# <930> LL/token: -7.84907
# <940> LL/token: -7.8476
# <950> LL/token: -7.8499
# <960> LL/token: -7.8472
# <970> LL/token: -7.84349
# <980> LL/token: -7.84297
# <990> LL/token: -7.84307
#
# 0	0.06374	upon holmes his which you but have sir very our then man your has watson sherlock there should however could
# 1	0.82863	and the that for his with have him all this are when will from there now more can has see
# 2	0.06462	not catherine very they for and but miss mrs tilney could such much their isabella morland general any thorpe being
# 3	0.43274	the and was had his with door were they but room into which there could not through them upon down
# 4	0.06079	the had sergeant franklin miss which rachel diamond room betteredge time when house lady own back your blake again cuff
# 5	0.07033	the upon not but have this its body all which any corpse has thus marie about madame now been what
# 6	0.0844	the that and emily but which had this was said montoni now not for who valancourt then they from she
# 7	0.62034	his and the with was him for that their them they had were himself who father than made more being
# 8	0.34776	and the but was which had that when with for from not yet these heart did its our more myself
# 9	0.52934	the was that had which been one this from would some not have were into found could for and who
# 10	0.02241	poirot inglethorp mrs not that was john yes cavendish but did room will she cynthia lawrence howard miss sir dorcas
# 11	0.04277	tuppence tommy the julius sir but james jane mrs thats they girl then vandemeyer dont guess brown she carter well
# 12	0.0239	the said manfred thou isabella gutenberg project this matilda not lord thy but theodore hippolita from princess prince thee work
# 13	0.51718	you not your have but that will would what this which are said shall know should may how then must
# 14	0.26502	the upon which this from but that your agnes antonia not every ambrosio lorenzo now matilda till still into bosom
# 15	0.21327	the and which they with their aubert from its over were some light where woods mountains upon among along while
# 16	0.61648	you was said the but what that not about out know there your little have very would did say them
# 17	0.58228	her she the and had was with for been from herself when all could before more which might time heart
# 18	0.04892	the and lord said sir his edmund you baron they will your him philip upon but them oswald all lovel
# 19	0.05411	not but all van helsing then for lucy some and time mina shall them which was could jonathan went sleep
#
# [beta: 0.02384]
# <1000> LL/token: -7.84081
#
# Total time: 1 minutes 57 seconds

# %% [markdown]
# # Appendix: README
#
# <a href="https://mimno.github.io/Mallet/topics">Download MALLET here</a> | <a href="https://github.com/ontoligent/mazo">Mazo, a wrapper around MALLET to organize its output.</a>
#
# [![Build Status](https://travis-ci.com/MNCC/Mallet.svg?branch=master)](https://travis-ci.com/MNCC/Mallet)
# [![codecov](https://codecov.io/gh/MNCC/Mallet/branch/master/graph/badge.svg)](https://codecov.io/gh/MNCC/Mallet)
#
# Mallet
# ======
#
# Website: https://mimno.github.io/Mallet/
#
# MALLET is a Java-based package for statistical natural language processing, document classification, clustering, topic modeling, information extraction, and other machine learning applications to text.
#
# MALLET includes sophisticated tools for document classification: efficient routines for converting text to "features", a wide variety of algorithms (including Naïve Bayes, Maximum Entropy, and Decision Trees), and code for evaluating classifier performance using several commonly used metrics.
#
# In addition to classification, MALLET includes tools for sequence tagging for applications such as named-entity extraction from text. Algorithms include Hidden Markov Models, Maximum Entropy Markov Models, and Conditional Random Fields. These methods are implemented in an extensible system for finite state transducers.
#
# Topic models are useful for analyzing large collections of unlabeled text. The MALLET topic modeling toolkit contains efficient, sampling-based implementations of Latent Dirichlet Allocation, Pachinko Allocation, and Hierarchical LDA.
#
# Many of the algorithms in MALLET depend on numerical optimization. MALLET includes an efficient implementation of Limited Memory BFGS, among many other optimization methods.
#
# In addition to sophisticated Machine Learning applications, MALLET includes routines for transforming text documents into numerical representations that can then be processed efficiently. This process is implemented through a flexible system of "pipes", which handle distinct tasks such as tokenizing strings, removing stopwords, and converting sequences into count vectors.
#
# An add-on package to MALLET, called GRMM, contains support for inference in general graphical models, and training of CRFs with arbitrary graphical structure.
#
# ## Installation
#
# To build a Mallet 2.0 development release, you must have the Apache ant build tool installed. From the command prompt, first change to the mallet directory, and then type
# `ant`
#
# If `ant` finishes with `"BUILD SUCCESSFUL"`, Mallet is now ready to use.
#
# If you would like to deploy Mallet as part of a larger application, it is helpful to create a single ".jar" file that contains all of the compiled code. Once you have compiled the individual Mallet class files, use the command:
# `ant jar`
#
# This process will create a file "mallet.jar" in the "dist" directory within Mallet.
#
# ## Usage
#
# Once you have installed Mallet you can use it using the following command:
# ```
# bin/mallet [command] --option value --option value ...
# ```
# Type `bin/mallet` to get a list of commands, and use the option `--help` with any command to get a description of valid options.
#
# For details about the commands please visit the API documentation and website at: https://mimno.github.io/Mallet/
#
#
# ## List of Algorithms
#
# * Topic Modelling
#   * LDA
#   * Parallel LDA
#   * DMR LDA
#   * Hierarchical LDA
#   * Labeled LDA
#   * Polylingual Topic Model
#   * Hierarchical Pachinko Allocation Model (PAM)
#   * Weighted Topic Model
#   * LDA with integrated phrase discovery
#   * Word Embeddings (word2vec) using skip-gram with negative sampling
# * Classification
#   * AdaBoost
#   * Bagging
#   * Winnow
#   * C45 Decision Tree
#   * Ensemble Trainer
#   * Maximum Entropy Classifier (Multinomial Logistic Regression)
#   * Naive Bayes
#   * Rank Maximum Entropy Classifier
#   * Posterior Regularization Auxiliary Model
# * Clustering
#   * Greedy Agglomerative
#   * Hill Climbing
#   * K-Means
#   * K-Best
# * Sequence Prediction Models
#   * Conditional Random Fields
#   * Maximum Entropy Markov Models
#   * Hidden Markov Models
#   * Semi-Supervised Sequence Prediction Models
# * Linear Regression
