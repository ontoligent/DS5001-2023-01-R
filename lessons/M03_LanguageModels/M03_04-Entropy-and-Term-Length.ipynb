# %% [markdown]
# # Metadata
#
# ```
# Course:  DS 5001
# module:  03
# topic:   Entropy and Term Length
# author:  R.C. Alvarado
# date:    12 Dec 2021
# purpose: This notebook describes the relationship between term length and entropy.
# ```

# %% [markdown]
# # Set Up

# %% [markdown]
# ## Config

# %%
data_home = '../data'
OHCO = ['book_id', 'chap_num', 'para_num', 'sent_num', 'token_num']

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly_express as px

# %%
sns.set()

# %% [markdown]
# ## Import Data

# %%
K = pd.read_csv(f"{data_home}/output/austen-combo-TOKENS.csv").set_index(OHCO)
V = pd.read_csv(f"{data_home}/output/austen-combo-VOCAB.csv").set_index('term_str')

# Add some features for this analysis
V['s'] = 1 / V.p

# %%
# K.head()

# %%
# V.head()

# %% [markdown]
# # Vocab $V$

# %% [markdown]
# ## Corpus frequency of terms
#
# Some words are very high frequency, but the vast majority have very low frequencies. We will explore the significane of this difference in the next module. NB: By "frequency" we mean relative frequency, which we use to estimate $p$.

# %%
V.p.sort_values(ascending=False).plot(style='.-', rot=45);

# %% [markdown]
# ## Frequency of frequencies
#
# The same data, but looked at in terms of the distribition of probabilities. This is so that it can be compared to the following graphs of $s$, $i$, and $h$.

# %%
V.p.round(4).value_counts().sort_index().plot(style='.-');

# %% [markdown]
# # Chismus Structure of $p$, $s$, $i$, and $h$

# %%
fig, axes = plt.subplots(ncols=2, nrows=2, figsize=(10,5), sharey='row')
fig.tight_layout(pad=2)
V.p.value_counts().sort_index().plot(style='.-', ax=axes[0,0], title="A1: $p$") 
V.s.value_counts().sort_index().plot(style='.-', ax=axes[0,1], title="B1: $s$")
V.i.value_counts().sort_index().plot(style='.-', ax=axes[1,1], title="B2: $i$") 
V.h.value_counts().sort_index().plot(style='.-', ax=axes[1,0], title="A2: $h$");

# %% [markdown]
# Note the range of $i$: it is one the same order as the range of `n_chars`.

# %% [markdown]
# # Compare $L$ to $p$, $s$, $i$, and $h$
#
# Now let's look at how these four features relate to term length $L$, the number of characters in a term (`n_chars`)

# %% [markdown]
# ## Create a dataframe for $L$

# %%
VG = V.groupby('n_chars')

# Distribution of L over the vocabulary (terms)
L = VG.n.count().to_frame('v_n')
L['v_p'] = L.v_n / L.v_n.sum()
L['v_s'] = 1 / L.v_p
L['v_i'] = np.log2(L.v_s)
L['v_h'] = L.v_p * L.v_i

# Distribution of L over the corpus (tokens)
L['k_n'] = VG.n.sum()
L['k_p'] = L.k_n / L.k_n.sum()
L['k_s'] = 1 / L.k_p
L['k_i'] = np.log2(L.k_s)
L['k_h'] = L.k_p * L.k_i

# Aggregate probability features over tokens
for func in ['sum','mean']:
    for x in 'psih':
        L[f"k{func}_{x}"] = VG[x].agg(func)    
        
# L.index.name = 'n_chars'        
L.columns = pd.Index([tuple(col.split('_')) for col in L.columns])
L.T.index.names = ['pop','stat']
Lnorm = (L - L.mean()) / L.std()

# %% [markdown]
# ## $L$ distributions
#
# Compare corpus and vocab frequencies. Why are the distributions different?

# %%
fig, axes = plt.subplots(nrows=2, ncols=2

#             background-color:  #e7e3f0;
#             color:  #000000;
#         }#T_6d123c86_66d2_11ec_85dc_acde48001122row0_col14,#T_6d123c86_66d2_11ec_85dc_acde48001122row6_col9{
#             background-color:  #63a2cb;
#             color:  #000000;
#         }#T_6d123c86_66d2_11ec_85dc_acde48001122row0_col15{
#             background-color:  #cacee5;
#             color:  #000000;
#         }#T_6d123c86_66d2_11ec_85dc_acde48001122row0_col16{
#             background-color:  #7bacd1;
#             color:  #000000;
#         }#T_6d123c86_66d2_11ec_85dc_acde48001122row0_col17{
#             background-color:  #6da6cd;
#             color:  #000000;
#         }#T_6d123c86_66d2_11ec_85dc_acde48001122row1_col0,#T_6d123c86_66d2_11ec_85dc_acde48001122row1_col1,#T_6d123c86_66d2_11ec_85dc_acde48001122row8_col3{
#             background-color:  #faf3f9;
#             color:  #000000;
#         }#T_6d123c86_66d2_11ec_85dc_acde48001122row1_col2{
#             background-color:  #f5eff6;
#             color:  #000000;
#         }#T_6d123c86_66d2_11ec_85dc_acde48001122row1_col3{
#             background-color:  #5a9ec9;
#             color:  #000000;
#         }#T_6d123c86_66d2_11ec_85dc_acde48001122row1_col4,#T_6d123c86_66d2_11ec_85dc_acde48001122row9_col3,#T_6d123c86_66d2_11ec_85dc_acde48001122row9_col5,#T_6d123c86_66d2_11ec_85dc_acde48001122row9_col6,#T_6d123c86_66d2_11ec_85dc_acde48001122row9_col10,#T_6d123c86_66d2_11ec_85dc_acde48001122row10_col13,#T_6d123c86_66d2_11ec_85dc_acde48001122row11_col9{
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }#T_6d123c86_66d2_11ec_85dc_acde48001122row1_col5,#T_6d123c86_66d2_11ec_85dc_acde48001122row1_col6,#T_6d123c86_66d2_11ec_85dc_acde48001122row1_col10{
#             background-color:  #0569a4;
#             color:  #f1f1f1;
#         }#T_6d123c86_66d2_11ec_85dc_acde48001122row1_col8,#T_6d123c86_66d2_11ec_85dc_acde48001122row4_col14,#T_6d123c86_66d2_11ec_85dc_acde48001122row5_col17,#T_6d123c86_66d2_11ec_85dc_acde48001122row11_col5,#T_6d123c86_66d2_11ec_85dc_acde48001122row11_col6,#T_6d123c86_66d2_11ec_85dc_acde48001122row11_col10,#T_6d123c86_66d2_11ec_85dc_acde48001122row14_col11{
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }#T_6d123c86_66d2_11ec_85dc_acde48001122row1_col9,#T_6d123c86_66d2_11ec_85dc_acde48001122row8_col11{
#             background-color:  #034d79;
#             color:

# %%
Lnorm.v.plot(figsize=(20,5))
# Out:
# <AxesSubplot:xlabel='n_chars'>

# %%
Lnorm.ksum.plot(figsize=(20,5));

# %% [markdown]
# **NOTE:** Notice how easy it is to combare features in the shaded table vs the chart.

# %% [markdown]
# ## Plot All

# %%
fig, axes = plt.subplots(ncols=4, nrows=6, figsize=(20,20), sharex=True)
fig.tight_layout(pad=2.5)
for i, x in enumerate(list("psih")):
    
#     ax = axes[0, i]
    
#     # Counts 
#     V[x].value_counts().plot(style='*-', ax=ax)
#     ax.set_title(f"${x}$")    

    ax = axes[0, i]
    
    # Means and points
    V.plot('n_chars', x, style='.', ax=ax, legend=False)
    L.kmean[x].plot(ax=ax);
    ax.set_title(f'corpus mean {x}')

    ax = axes[1, i]
    
    # Variances 
    sns.boxplot(data=V.reset_index(), x='n_chars', y=x, ax=ax)
    ax.set_title(f'corpus variance {x}')

    ax = axes[2, i]

    # Ksum
    L.ksum[x].plot(ax=ax)
    ax.set_title(f'corpus sum {x}')
    
    ax = axes[3, i]
    
    # Kmean
    L.kmean[x].plot(ax=ax)
    ax.set_title(f"corpus mean {x}")

    ax = axes[4, i]
    
    # K
    L.k[x].plot(ax=ax)
    ax.set_title(f"corpus {x}")

    ax = axes[5, i]
    
    # V
    L.v[x].plot(ax=ax)
    ax.set_title(f"vocab {x}")

# %%
def plot_chiasmus(df, kind='bar'):
    fig, axes = plt.subplots(ncols=2, nrows=2, figsize=(10,6), sharex=True)
    fig.tight_layout()
    df.p.plot(kind=kind, ax=axes[0,0], title='P')
    df.s.plot(kind=kind, ax=axes[0,1], title='S')
    df.i.plot(kind=kind, ax=axes[1,1], title='I', rot=0)
    df.h.plot(kind=kind, ax=axes[1,0], title='H', rot=0)

# %%
# plot_chiasmus(Lnorm.v, 'bar')

# %%
# plot_chiasmus(Lnorm.k, 'bar')

# %%
# plot_chiasmus(Lnorm.ksum, 'bar')

# %%
# plot_chiasmus(Lnorm.kmean, 'bar')

# %% [markdown]
# # Conclusions
#
# * All high frequency, low information terms are short.
# * Average term length increase with information.
# * Information and term length in fact have the same scale! They are weakly correlated; $0.3$
#   * Characters as units of information.
# * $s$ or $i$ can be used to cull significant terms.
# * The bulk of surprise is in the seven letter words.
#   * Does this mean that the vocabulary frequency of character length is short cut to computing the entropy of character length types?

# %% [markdown]
# # Explore Term Length Vector Space
#
# Can we learn anything about the structure of our corpus from distribution of term lengths? If information is related to length, there must be something to observe.

# %%
import sys; sys.path.append('../lib')
from hac import HAC

# %%
K['n_chars'] = K.term_str.str.len()

# %%
T1 = K.groupby(OHCO[:2]+['n_chars']).n_chars.count().unstack(fill_value=0)

T2 = (T1.T / T1.T.sum()).T

T3 = T2.corr().stack().sort_values().to_frame('c')
T3.index.names = ['x','y']
T3 = T3[T3.apply(lambda x: x.name[0] > x.name[1], 1)]
T3 = T3.sort_values('c', ascending=False)

# %% [markdown]
# ## Book 1 (SS)

# %%
T1.loc[1, 5:].style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
# #T_3c6d199e_6721_11ec_85dc_acde48001122row0_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row1_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row2_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row3_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row4_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row5_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row6_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row7_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row8_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row9_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row9_col1,#T_3c6d199e_6721_11ec_85dc_acde48001122row10_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row11_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row12_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row13_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row14_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row15_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row16_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row17_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row18_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row19_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row20_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row21_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row22_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row23_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row24_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row25_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row26_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row27_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row28_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row29_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row30_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row31_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row32_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row33_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row34_col1,#T_3c6d199e_6721_11ec_85dc_acde48001122row35_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row36_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row37_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row38_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row39_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row40_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row41_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row42_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row43_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row44_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row45_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row46_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row47_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row48_col0,#T_3c6d199e_6721_11ec_85dc_acde48001122row49_col0{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_3c6d199e_6721_11ec_85dc_acde48001122row0_col1{
#             background-color:  #056caa;
#             color:  #f1f1f1;
#         }#T_3c6d199e_6721_11ec_85dc_acde48001122row0_col2,#T_3c6d199e_6721_11ec_85dc_acde48001122row12_col1{
#             background-color:  #308cbe;
#             color:  #000000;
#         }#T_3c6d199e_6721_11ec_85dc_acde48001122row0_col3,#T_3c6d199e_6721_11ec_85dc_acde48001122row34_col2{
#             background-color:  #4496c3;
#             color:  #000000;
#         }#T_3c6d199e_6721_11ec_85dc_acde48001122row0_col4,#T_3c6d199e_6721_11ec_85dc_acde48001122row45_col5{
#             background-color:  #b7c5df;
#             color:  #000000;
#         }#T_3c6d199e_6721_11ec_85dc_acde48001122row0_col5,#T_3c6d199e_6721_11ec_85dc_acde48001122row12_col5,#T_3c6d199e_6721_11ec_85dc_acde48001122row23_col5,#T_3c6d199e_6721_11ec_85dc_acde48001122row38_col5,#T_3c6d199e_6721_11ec_85dc_acde48001122row40_col5{
#             background-color:  #dddbec;
#             color:  #000000;
#         }#T

#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_be0e820e_6720_11ec_85dc_acde48001122row0_col1,#T_be0e820e_6720_11ec_85dc_acde48001122row11_col2{
#             background-color:  #056dab;
#             color:  #f1f1f1;
#         }#T_be0e820e_6720_11ec_85dc_acde48001122row0_col2{
#             background-color:  #63a2cb;
#             color:  #000000;
#         }#T_be0e820e_6720_11ec_85dc_acde48001122row0_col3,#T_be0e820e_6720_11ec_85dc_acde48001122row8_col4{
#             background-color:  #79abd0;
#             color:  #000000;
#         }#T_be0e820e_6720_11ec_85dc_acde48001122row0_col4,#T_be0e820e_6720_11ec_85dc_acde48001122row16_col4{
#             background-color:  #afc1dd;
#             color:  #000000;
#         }#T_be0e820e_6720_11ec_85dc_acde48001122row0_col5,#T_be0e820e_6720_11ec_85dc_acde48001122row22_col5{
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }#T_be0e820e_6720_11ec_85dc_acde48001122row0_col6,#T_be0e820e_6720_11ec_85dc_acde48001122row15_col7{
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }#T_be0e820e_6720_11ec_85dc_acde48001122row0_col7,#T_be0e820e_6720_11ec_85dc_acde48001122row5_col6,#T_be0e820e_6720_11ec_85dc_acde48001122row9_col6,#T_be0e820e_6720_11ec_85dc_acde48001122row11_col6,#T_be0e820e_6720_11ec_85dc_acde48001122row18_col7{
#             background-color:  #f3edf5;
#             color:  #000000;
#         }#T_be0e820e_6720_11ec_85dc_acde48001122row0_col8,#T_be0e820e_6720_11ec_85dc_acde48001122row7_col8,#T_be0e820e_6720_11ec_85dc_acde48001122row11_col8,#T_be0e820e_6720_11ec_85dc_acde48001122row19_col8{
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }#T_be0e820e_6720_11ec_85dc_acde48001122row0_col9,#T_be0e820e_6720_11ec_85dc_acde48001122row3_col10,#T_be0e820e_6720_11ec_85dc_acde48001122row13_col8{
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }#T_be0e820e_6720_11ec_85dc_acde48001122row0_col10,#T_be0e820e_6720_11ec_85dc_acde48001122row1_col9,#T_be0e820e_6720_11ec_85dc_acde48001122row1_col10,#T_be0e820e_6720_11ec_85dc_acde48001122row7_col9,#T_be0e820e_6720_11ec_85dc_acde48001122row10_col9,#T_be0e820e_6720_11ec_85dc_acde48001122row16_col9,#T_be0e820e_6720_11ec_85dc_acde48001122row18_col9,#T_be0e820e_6720_11ec_85dc_acde48001122row19_col10,#T_be0e820e_6720_11ec_85dc_acde48001122row20_col9{
#             background-color:  #fef6fa;
#             color:  #000000;
#         }#T_be0e820e_6720_11ec_85dc_acde48001122row0_col11,#T_be0e820e_6720_11ec_85dc_acde48001122row0_col12,#T_be0e820e_6720_11ec_85dc_acde48001122row1_col11,#T_be0e820e_6720_11ec_85dc_acde48001122row1_col12,#T_be0e820e_6720_11ec_85dc_acde48001122row2_col10,#T_be0e820e_6720_11ec_85dc_acde48001122row2_col11,#T_be0e820e_6720_11ec_85dc_acde48001122row2_col12,#T_be0e820e_6720_11ec_85dc_acde48001122row3_col11,#T_be0e820e_6720_11ec_85dc_acde48001122row3_col12,#T_be0e820e_6720_11ec_85dc_acde48001122row4_col9,#T_be0e820e_6720_11ec_85dc_acde48001122row4_col10,#T_be0e820e_6720_11ec_85dc_acde48001122row4_col11,#T_be0e820e_6720_11ec_85dc_acde48001122row4_col12,#T_be0e820e_6720_11ec_85dc_acde48001122row5_col9,#T_be0e820e_6720_11ec_85dc_acde48001122row5_col10,#T_be0e820e_6720_11ec_85dc_acde48001122row5_col11,#T_be0e820e_6720_11ec_85dc_acde48001122row5_col12,#T_be0e820e_6720_11ec_85dc_acde48001122row6_col10,#T_be0e820e_6720_11ec_85dc_acde48001122row6_col11,#T_be0e820e_6720_11ec_85dc_acde48001122row6_col12,#T_be0e820e_6720_11ec_85dc_acde48001122row7_col10,#T_be0e820e_6720_11ec_85dc_acde48001122row7_col11,#T_be0e820e_6720_11ec_85dc_acde48001122row7_col12,#T_be0e820e_6720_11ec_85dc_acde48001122row8_col9,#T_be0e820e_6720_11ec_85dc_acde48001122row8_col10,#T_be0e820e_6720_11ec_85dc_acde48001122row8_col11,#T_be0e820e_6720_11ec_85dc_acde48001122row8_col12,#T_be0e820e_6720_11ec_85dc_acde48001122row9_col10,#T_be0e820e_6720_11ec_85dc_acde48001122row9_col11,#T_be0e820e_6720_11ec_85dc_acde48001122row9_col12,#T_be0e820e_6720_11ec_85dc_acde48001122row10_col10,#T_be0e820e_6720_11ec_85dc_acde48001122row10_col11,#T_be0e820e_6720_11ec_85dc_acde48001122row10_col12,#T_be0e820e_6720_11ec_85dc_acde48001122row11_col10,#T_be0e820e_6720_11ec_85dc_acde48001122row11_col11,#T_be0e820e_6720_11ec_85dc_acde48001122row11_col12,#T_be0e820e_6720_11ec_85dc_acde48001122row12_col10,#T_be0e820e_6720_11ec_85dc_acde48001122row12_col11,#T_be0e820e_6720_11ec_85dc_acde48001122row12_col12,#T_be0e820e_6720_11ec_85dc_acde48001122row13_col11,#T_be0e820e_6720_11ec_85dc_acde48001122row13_col12,#T_be0e820e_6720_11ec_85dc_acde48001122row14_col11,#T_be0e820e_6720_11ec_85dc_acde48001122row14_col12,#T_be0e820e_6720_11ec_85dc_acde48001122row15_col10,#T_be0e820e_6720_11ec_85dc_acde48001122row15_col11,#T_be0e820e_6720_11ec_85dc_acde48001122row15_col12,#T_be0e820e_6720_11ec_85dc_acde48001122row16_col10,#T_be0e820e_6720_11ec_85dc_acde48001122row16_col11,#T_be0e820e_6720_11ec_85dc_acde48001122row16_col12,#T_be0e820e_6720_11ec_85dc_acde48001122row17_col9,#T_be0e820e_6720_11ec_85dc_acde48001122row17_col10,#T_be0e820e_6720_11ec_85dc_acde48001122row17_col11,#T_be0e820e_6720_11ec_85dc_acde48001122row17_col12,#T_be0e820e_6720_11ec_85dc_acde48001122row18_col10,#T_be0e820e_6720_11ec_85dc_acde48001122row18_col11,#T_be0e820e_6720_11ec_85dc_acde48001122row18_col12,#T_be0e820e_6720_11ec_85dc_acde48001122row19_col11,#T_be0e820e_6720_11ec_85dc_acde48001122row19_col12,#T_be0e820e_6720_11ec_85dc_acde48001122row20_col10,#T_be0e820e_6720_11ec_85dc_acde48001122row20_col11,#T_be0e820e_6720_11ec_85dc_acde48001122row20_col12,#T_be0e820e_6720_11ec_85dc_acde48001122row21_col11,#T_be0e820e_6720_11ec_85dc_acde48001122row21_col12,#T_be0e820e_6720_11ec_85dc_acde48001122row22_col10,#T_be0e820e_6720_11ec_85dc_acde48001122row22_col11,#T_be0e820e_6720_11ec_85dc_acde48001122row22_col12,#T_be0e820e_6720_11ec_85dc_acde48001122row23_col10,#T_be0e820e_6720_11ec_85dc_acde48001122row23_col11,#T_be0e820e_6720_11ec_85dc_acde48001122row23_col12{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_be0e820e_6720_11ec_85dc_acde48001122row1_col1{
#             background-color:  #0d75b3;
#             color:  #f1f1f1;
#         }#T_be0e820e_6720_11ec_85dc_acde48001122row1_col2,#T_be0e820e_6720_11ec_85dc_acde48001122row22_col2{
#             background-color:  #358fc0;
#             color:  #000000;
#         }#T_be0e820e_6720_11ec_85dc_acde48001122row1_col3,#T_be0e820e_6720_11ec_85dc_acde48001122row11_col3{
#             background-color:  #86b0d3;
#             color:  #000000;
#         }#T_be0e820e_6720_11ec_85dc_acde48001122row1_col4{
#             background-color:  #a5bddb;
#             color:  #000000;
#         }#T_be0e820e_6720_11ec_85dc_acde48001122row1_col5,#T_be0e820e_6720_11ec_85dc_acde48001122row4_col5,#T_be0e820e_6720_11ec_85dc_acde48001122row12_col5{

# %%
sns.boxplot(data=T2.loc[2]);

# %%
# sns.relplot?

# %%
sns.relplot(data=T2.loc[2], kind='line', aspect=2.5);

# %%
HAC(T2.loc[2]).plot()
