# %% [markdown]
# # Metadata
#
# ```yaml
# Course:  DS 5001
# Module:  03 Lab
# Topic:   Inferring Language Models
# Version: 3
# Author:  R.C. Alvarado
# Date:    22 January 2022 (modified)
# ```
#
# **Purpose**:  Wew create word-level langage models from a set of novels and evaluate them.

# %% [markdown]
# # Set Up

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re
import seaborn as sns
from IPython.core.display import HTML

# %%
sns.set()

# %% [markdown]
# ## Configure

# %%
data_home = '../data'

# %%
OHCO = ['book_id', 'chap_num', 'para_num', 'sent_num', 'token_num']
text_file = f'{data_home}/output/austen-combo.csv' # Generated in HW 02

# %%
ngram_size = 3

# Add-k Smoothing parameter
k = .1

# %% [markdown]
# # Get Training Data
#
# Problem: These texts treat Mr. and Mrs. as sentences. Since sentence breaks are represented in the OHCO, to fix this requires reparsing the source text into the TOKEN table with the abbreviation periods removed.

# %% [markdown]
# ## Import TOKENS
#
# We use our way of representing a text as input. Normally, `term_str` would already be included in the dataframe.

# %%
TOKENS = pd.read_csv(text_file).set_index(OHCO).dropna()
TOKENS['term_str'] = TOKENS.token_str.str.lower().str.replace(r'[\W_]+', '', regex=True)
TOKENS = TOKENS[TOKENS.term_str != '']

# %%
TOKENS.head()
# Out:
#                                              token_str  term_str
# book_id chap_num para_num sent_num token_num
# 1       1        1        0        0               The       the
#                                    1            family    family
#                                    2                of        of
#                                    3          Dashwood  dashwood
#                                    4               had       had

# %% [markdown]
# Look at book 2 (_Persuasion_) only:

# %%
TOKENS.loc[2].head()
# Out:
#                                      token_str  term_str
# chap_num para_num sent_num token_num
# 1        0        0        0               Sir       sir
#                            1            Walter    walter
#                            2            Elliot    elliot
#                            3                of        of
#                            4          Kellynch  kellynch

# %% [markdown]
# ## Extract VOCAB from TOKENS

# %%
VOCAB = TOKENS.term_str.value_counts().to_frame('n').sort_index()
VOCAB.index.name = 'term_str'
VOCAB['n_chars'] = VOCAB.index.str.len()

# %%
VOCAB.head()
# Out:
#           n  n_chars
# term_str
# 1         3        1
# 15        1        2
# 16        1        2
# 1760      1        4
# 1784      1        4

# %% [markdown]
# # Handle OOV Terms
#
# We handle out-of-vocabulary (OOV) terms by replacing some of our single-instance (i.e. [_hapax legomena_](https://en.wikipedia.org/wiki/Hapax_legomenon)) words with the `<UNK>` sign.

# %% [markdown]
# ## Compute HAPAX info
#
# To select a subset from the set of hapax terms, we use the probability features of terms based on length.
#
# Intuition: This prevents us from getting rid of "good" words that appear in low frequency.

# %%
HAPAX = VOCAB[VOCAB.n == 1].n_chars.value_counts().to_frame('n').sort_index() 
HAPAX.index.name = 'n_chars'

# %%
# HAPAX

# %%
HAPAX.plot();

# %%
HAPAX['p'] = HAPAX.n / HAPAX.n.sum()
HAPAX['s'] = 1/HAPAX.p
HAPAX['i'] = np.log2(HAPAX.s)
HAPAX['h'] = HAPAX.p * HAPAX.i
H = HAPAX.h.sum().round(2)
H_max = np.log2(HAPAX.shape[0]).round(2)
R = (1 - H/H_max).round(2) * 100

# %%
H, H_max, R
# Out:
# (3.32, 4.09, 19.0)

# %%
HAPAX.style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_27cd6_row0_col0,#T_27cd6_row0_col1,#T_27cd6_row4_col2,#T_27cd6_row10_col2{
#             background-color:  #fef6fb;
#             color:  #000000;
#         }#T_27cd6_row0_col2{
#             background-color:  #75a9cf;
#             color:  #000000;
#         }#T_27cd6_row0_col3{
#             background-color:  #045b8f;
#             color:  #f1f1f1;
#         }#T_27cd6_row0_col4,#T_27cd6_row3_col2,#T_27cd6_row11_col2{
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }#T_27cd6_row1_col0,#T_27cd6_row1_col1,#T_27cd6_row8_col3{
#             background-color:  #fef6fa;
#             color:  #000000;
#         }#T_27cd6_row1_col2{
#             background-color:  #a8bedc;
#             color:  #000000;
#         }#T_27cd6_row1_col3{
#             background-color:  #0566a0;
#             color:  #f1f1f1;
#         }#T_27cd6_row1_col4{
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }#T_27cd6_row2_col0,#T_27cd6_row2_col1,#T_27cd6_row14_col4{
#             background-color:  #f5eef6;
#             color:  #000000;
#         }#T_27cd6_row2_col2{
#             background-color:  #f3edf5;
#             color:  #000000;
#         }#T_27cd6_row2_col3{
#             background-color:  #6da6cd;
#             color:  #000000;
#         }#T_27cd6_row2_col4{
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }#T_27cd6_row3_col0,#T_27cd6_row3_col1{
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }#T_27cd6_row3_col3{
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }#T_27cd6_row3_col4{
#             background-color:  #73a9cf;
#             color:  #000000;
#         }#T_27cd6_row4_col0,#T_27cd6_row4_col1{
#             background-color:  #3d93c2;
#             color:  #000000;
#         }#T_27cd6_row4_col3{
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }#T_27cd6_row4_col4{
#             background-color:  #056dab;
#             color:  #f1f1f1;
#         }#T_27cd6_row5_col0,#T_27cd6_row5_col1{
#             background-color:  #046299;
#             color:  #f1f1f1;
#         }#T_27cd6_row5_col2,#T_27cd6_row6_col2,#T_27cd6_row6_col3,#T_27cd6_row7_col2,#T_27cd6_row7_col3,#T_27cd6_row8_col2,#T_27cd6_row9_col2,#T_27cd6_row15_col0,#T_27cd6_row15_col1,#T_27cd6_row15_col4,#T_27cd6_row16_col0,#T_27cd6_row16_col1,#T_27cd6_row16_col4{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_27cd6_row5_col3{
#             background-color:  #faf2f8;
#             color:  #000000;
#         }#T_27cd6_row5_col4{
#             background-color:  #034f7d;
#             color:  #f1f1f1;
#         }#T_27cd6_row6_col0,#T_27cd6_row6_col1,#T_27cd6_row6_col4,#T_27cd6_row7_col0,#T_27cd6_row7_col1,#T_27cd6_row7_col4,#T_27cd6_row15_col2,#T_27cd6_row15_col3,#T_27cd6_row16_col2,#T_27cd6_row16_col3{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_27cd6_row8_col0,#T_27cd6_row8_col1{
#             background-color:  #03476f;
#             color:  #f1f1f1;
#         }#T_27cd6_row8_col4{
#             background-color:  #023e62;
#             color:  #f1f1f1;
#         }#T_27cd6_row9_col0,#T_27cd6_row9_col1{
#             background-color:  #328dbf;
#             color:  #000000;
#         }#T_27cd6_row9_col3,#T_27cd6_row13_col2{
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }#T_27cd6_row9_col4{
#             background-color:  #0569a5;
#             color:  #f1f1f1;
#         }#T_27cd6_row10_col0,#T_27cd6_row10_col1,#T_27cd6_row11_col4{
#             background-color:  #78abd0;
#             color:  #000000;
#         }#T_27cd6_row10_col3{
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }#T_27cd6_row10_col4{
#             background-color:  #2484ba;
#             color:  #000000;
#         }#T_27cd6_row11_col0,#T_27cd6_row11_col1{
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }#T_27cd6_row11_col3{
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }#T_27cd6_row12_col0,#T_27cd6_row12_col1{
#             background-color:  #ece7f2;
#             color:  #000000;
#         }#T_27cd6_row12_col2{
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }#T_27cd6_row12_col3{
#             background-color:  #9ebad9;
#             color:  #000000;
#         }#T_27cd6_row12_col4{
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }#T_27cd6_row13_col0,#T_27cd6_row13_col1{
#             background-color:  #f5eff6;
#             color:  #000000;
#         }#T_27cd6_row13_col3{
#             background-color:  #67a4cc;
#             color:  #000000;
#         }#T_27cd6_row13_col4{
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }#T_27cd6_row14_col0,#T_27cd6_row14_col1{
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }#T_27cd6_row14_col2{
#             background-color:  #dddbec;
#             color:  #000000;
#         }#T_27cd6_row14_col3{
#             background-color:  #2081b9;
#             color:  #000000;
#         }</style><table id="T_27cd6_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >n</th>        <th class="col_heading level0 col1" >p</th>        <th class="col_heading level0 col2" >s</th>        <th class="col_heading level0 col3" >i</th>        <th class="col_heading level0 col4" >h</th>    </tr>    <tr>        <th class="index_name level0" >n_chars</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_27cd6_level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_27cd6_row0_col0" class="data row0 col0" >6</td>
#                         <td id="T_27cd6_row0_col1" class="data row0 col1" >0.001933</td>
#                         <td id="T_27cd6_row0_col2" class="data row0 col2" >517.333333</td>
#                         <td id="T_27cd6_row0_col3" class="data row0 col3" >9.014950</td>
#                         <td id="T_27cd6_row0_col4" class="data row0 col4" >0.017426</td>
#             </tr>
#             <tr>
#                         <th id="T_27cd6_level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_27cd6_row1_col0" class="data row1 col0" >8</td>
#                         <td id="T_27cd6_row1_col1" class="data row1 col1" >0.002577</td>
#                         <td id="T_27cd6_row1_col2" class="data row1 col2" >388.000000</td>
#                         <td id="T_27cd6_row1_col3" class="data row1 col3" >8.599913</td>
#                         <td id="T_27cd6_row1_col4" class="data row1 col4" >0.022165</td>
#             </tr>
#             <tr>
#                         <th id="T_27cd6_level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_27cd6_row2_col0" class="data row2 col0" >35</td>
#                         <td id="T_27cd6_row2_col1" class="data row2 col1" >0.011276</td>
#                         <td id="T_27cd6_row2_col2" class="data row2 col2" >88.685714</td>
#                         <td id="T_27cd6_row2_col3" class="data row2 col3" >6.470630</td>
#                         <td id="T_27cd6_row2_col4" class="data row2 col4" >0.072961</td>
#             </tr>
#             <tr>
#                         <th id="T_27cd6_level0_row3" class="row_heading level0 row3" >4</th>
#                         <td id="T_27cd6_row3_col0" class="data row3 col0" >152</td>
#                         <td id="T_27cd6_row3_col1" class="data row3 col1" >0.048969</td>
#                         <td id="T_27cd6_row3_col2" class="data row3 col2" >20.421053</td>
#                         <td id="T_27cd6_row3_col3" class="data row3 col3" >4.351985</td>
#                         <td id="T_27cd6_row3_col4" class="data row3 col4" >0.213113</td>
#             </tr>
#             <tr>
#                         <th id="T_27cd6_l

# %%
(HAPAX / HAPAX.mean())[['p','h']].plot();

# %% [markdown]
# Aside: Note how entropy "regularizes" probability, lowering the higher probabilities and raising the lower ones.

# %% [markdown]
# ## Method 1: Mean Self-Entropy

# %%
HAPAX.h.plot(title="Entropy by Word Length")
HM = HAPAX.h.mean() # Use mean self-entropy as threshhold
plt.axhline(y=HM, color='orange');

# %%
unk_list_h = HAPAX[HAPAX.h < HM].index.to_list()

# %%
unk_list_h
# Out:
# [1, 2, 3, 13, 14, 15, 16, 17]

# %% [markdown]
# ## Method 2: Mean Information

# %%
hapax_mean = HAPAX.i.mean() # Use mean as threshhold

# %%
HAPAX.i.plot(title="Information by Word Length")
plt.axhline(y=hapax_mean, color='orange');

# %% [markdown]
# Get lengths that are below the average information (or self-entropy).

# %%
unk_list_i = HAPAX[HAPAX.i > hapax_mean].index.to_list()

# %%
unk_list_i
# Out:
# [1, 2, 3, 13, 14, 15, 16, 17]

# %% [markdown]
# Keep the words with lengths with `i` or `h` below the mean.

# %%
UNK = VOCAB[VOCAB.n_chars.isin(unk_list_i) & (VOCAB.n == 1)].index.to_list()

# %%
HTML(' '.join(UNK))
# Out:
# 15 16 1st 20 200 9 acknowledgements acquaintances administering aggrandizement aim anticipations ash au bee brotherliness characteristic circumspection circumstanced circumventing cod commiseration communications companionableness comprehensible condescending congratulating connoisseurship conscientiously consternation constitutional consultations contemplating corresponding cot counteracting counterbalance demonstrations desirableness disadvantages disagreements discriminating discrimination disengagement disinterestedness disqualifications disrespectful dissatisfaction e eligibilities em encouragements encroachments enfranchisement err expensiveness extraordinarily fastidiousness fed felicitations fir forgetfulness fox gad grandchildren ham hey hid hit ho hon hop hue hum ice imperfections impoverishing impracticable inadvertencies incautiousness inconsiderately indefatigable independently indistinctness inexhaustible inexpressibly inquisitiveness insignificance instantaneous insufficiency insurmountable intrinsically introductions irreconcilable jar l leg mab mad mar mediterranean mid misconstructions n net non obtrusiveness ostentatiously overspreading p particularize personableness philanthropic possibilities prepossessing prescriptions professionally proportionately pry qualification qualifications rat reasonableness recapitulation relinquishment reprehensible representative representatives reproachfully resuscitation retrenchments retrospections rug rut sarcastically sequestration sin solicitations spontaneously strengthening superannuated superiorities thoughtlessness tranquillized transgressions unaccountably unconquerable unconsciousness undesirableness unexceptionable unexhilarating unfashionable unintelligible unintentional uninteresting unnecessarily unobjectionable unobtrusiveness unpersuadable unpleasantest unproductively unreasonableness unsuitableness ve wm woe z

# %% [markdown]
# ## Create Training sentences and vocab

# %% [markdown]
# Grab terms (normalized tokens) from TOKENS.

# %%
TOKENS['term_str_train'] = TOKENS.term_str

# %% [markdown]
# Replace unknowns.

# %%
TOKENS.loc[TOKENS.term_str.isin(UNK), 'term_str_train'] = '<UNK>'

# %% [markdown]
# Convert tokens to sentences.

# %%
S_TRAIN = list(TOKENS.groupby(OHCO[:-1]).term_str_train.apply(lambda x: ' '.join(x)).values)

# %% [markdown]
# Inspect results:

# %%
S_TRAIN[:5]
# Out:
# ['the family of dashwood had long been settled in sussex',
#  'their estate was large and their residence was at norland park in the centre of their property where for many generations they had lived in so respectable a manner as to engage the general good opinion of their surrounding acquaintance',
#  'the late owner of this estate was a single man who lived to a very advanced age and who for many years of his life had a constant companion and housekeeper in his sister',
#  'but her death which happened ten years before his own produced a great alteration in his home',
#  'for to supply her loss he invited and received into his house the family of his nephew mr']

# %% [markdown]
# Extract the training VOCAB as a list.

# %%
# V_TRAIN = TOKENS.term_str_train.drop_duplicates().sort_values().to_list()
V_TRAIN = sorted(list(set(VOCAB.index) - set(UNK))  + ['<UNK>'])

# %% [markdown]
# Inspect a slice.

# %%
V_TRAIN[100:105]
# Out:
# ['accustomary', 'aches', 'aching', 'acknowledge', 'acknowledged']

# %% [markdown]
# # Train Models
#
# We now create a dataframe of ngrams, calculating MLE and with smoothing.

# %% [markdown]
# ## Parameters

# %% [markdown]
# Create names used for ngram element columns (`w0`, `w1`, etc.)

# %%
widx = [f'w{i}' for i in range(ngram_size)]

# %% [markdown]
# ## Model
#
# We define a class to compute n-gram counts. These counts will be used in our models below.

# %%
class NgramCounter():
    
    def __init__(self, sents:[], vocab:[], n:int=3):
        self.sents = sents
        self.vocab = vocab
        self.n = n
        self.widx = [f'w{i}' for i in range(self.n)]
        
    def generate(self):
        
        self.S = pd.DataFrame(dict(sent_str=self.sents))
    
        # Pad sentences 
        pad = '<s> ' *  (self.n - 1)
        
        self.I = (pad + self.S.sent_str + ' </s>')\
            .str.split(expand=True).stack().to_frame('w0')
        self.I.index.names = ['sent_num', 'token_num']
        self.I.loc[~self.I.w0.isin(self.vocab + ['<s>','</s>']), 'w0'] = '<UNK>'

        # Get sentence lengths (these include pads)
        self.S['len'] = self.I.groupby('sent_num').w0.count()
                
        # Add w columns
        for i in range(1, self.n): 
            self.I[f'w{i}'] = self.I[f"w{i-1}"].shift(-1)         
        
        # Generate ngrams
        self.NG = []
        for i in range(self.n):
            self.NG.append(self.I.iloc[:, :i+1].copy())
           
            # Remove spurious rows
#             self.NG[i] = self.NG[i].query(f"w{i} != '<s>'")
                    
        # Generate counts
        self.LM = []
        for i in range(self.n):
            self.LM.append(self.NG[i].value_counts().to_frame('n')) # 2 offset is to remove blank lines

        # Hack to remove single value tuple ...
        self.LM[0].index = [i[0] for i in self.LM[0].index]
        self.LM[0].index.name = 'w0'

# %%
train = NgramCounter(S_TRAIN, V_TRAIN)
train.generate()

# %%
train.NG[2].loc[0]
# Out:
#                  w0        w1        w2
# token_num
# 0               <s>       <s>       the
# 1               <s>       the    family
# 2               the    family        of
# 3            family        of  dashwood
# 4                of  dashwood       had
# 5          dashwood       had      long
# 6               had      long      been
# 7              long      been   settled
# 8              been   settled        in
# 9           settled        in    sussex
# 10               in    sussex      </s>
# 11           sussex      </s>       <s>
# 12             </s>       <s>       <s>

# %%
class NgramLanguageModel():
    
    k:float = .5
    
    def __init__(self, ngc:NgramCounter):
        self.S = ngc.S
        self.LM = ngc.LM
        self.NG = ngc.NG
        self.n = ngc.n
        
    def apply_smoothing(self):
        
        self.Z1 = [None for i in range(self.n)] # Unseen N grams, but seen N-1 grams
        self.Z2 = [None for i in range(self.n)] # Unsess N-1 grams too
        V = len(self.LM[0])

        for i in range(self.n):      
            
            # Joint probabilities
            B = V**(i+1)
            self.LM[i]['p'] = (self.LM[i].n + self.k) / (self.LM[i].n.sum() + B * self.k)
            self.LM[i]['log_p'] = np.log2(self.LM[i].p)

            if i > 0:
            
                # Conditional probabilities
                self.LM[i]['cp'] = self.LM[i].p / self.LM[i-1].p
                self.LM[i]['log_cp'] = np.log2(self.LM[i].cp)

                # Handle unseen data
                self.LM[i].sort_index(inplace=True)     
                self.Z1[i] = np.log2(self.k / (self.LM[i-1].n + B*self.k))
                self.Z2[i] = np.log2(self.k / B*self.k)

    def predict(self, test):
        self.T = test
        self.PP = []
        p_key = 'log_cp'
        for i in range(self.n):
            ng = i + 1
            if i == 0:
                self.T.S[f'ng_{ng}_ll'] = self.T.NG[0].join(self.LM[0].log_p, on=widx[:ng])\
                    .groupby('sent_num').log_p.sum()
            else:
                self.T.S[f'ng_{ng}_ll'] = self.T.NG[i].join(self.LM[i][p_key], on=widx[:ng])\
                    .fillna(Z1[i]).fillna(Z2[i])\
                    .groupby('sent_num')[p_key].sum()
                
            self.T.S[f'pp{ng}'] = 2**( -self.T.S[f'ng_{ng}_ll'] / self.T.S['len'])

# %%
# def get_pp(self, sent_str):
        # pp = 2 ** -(
        #   sum(mle.logprob(word) for word in sample.split())
        #   /
        #   len(sample.split())
        # )

# %%
# model = NgramLanguageModel(S_TRAIN, V_TRAIN)
model = NgramLanguageModel(train)
model.k = 1
model.apply_smoothing()

# %%
NG = model.NG
LM = model.LM
Z1 = model.Z1
Z2 = model.Z2

# %%
LM[2].sort_index()
# Out:
#                                 n             p      log_p        cp  \
# w0        w1          w2
# 1         1760        married   1  3.799825e-12 -37.937204  0.000124
#           1785        </s>      1  3.799825e-12 -37.937204  0.000124
#           ends        </s>      1  3.799825e-12 -37.937204  0.000124
# 1760      married     july      1  3.799825e-12 -37.937204  0.000124
# 1784      elizabeth   daughter  1  3.799825e-12 -37.937204  0.000124
# ...                            ..           ...        ...       ...
# zealous   attention   as        1  3.799825e-12 -37.937204  0.000124
#           officer     too       1  3.799825e-12 -37.937204  0.000124
#           on          the       1  3.799825e-12 -37.937204  0.000124
# zealously active      as        1  3.799825e-12 -37.937204  0.000124
#           discharging all       1  3.799825e-12 -37.937204  0.000124
#
#                                    log_cp
# w0        w1          w2
# 1         1760        married  -12.973642
#           1785        </s>     -12.973642
#           ends        </s>     -12.973642
# 1760      married     july     -12.973642
# 1784      elizabeth   daughter -12.973642
# ...                                   ...
# zealous   attention   as       -12.973642
#           officer     too      -12.973642
#           on          the      -12.973642
# zealously active      as       -12.973642
#           discharging all      -12.973642
#
# [160317 rows x 5 columns]

# %%
LM[2].loc[('anne', 'was')].sort_values('n', ascending=False)
# Out:
#              n             p      log_p        cp     log_cp
# w2
# not          2  5.699737e-12 -37.352242  0.000008 -16.973642
# at           2  5.699737e-12 -37.352242  0.000008 -16.973642
# startled     2  5.699737e-12 -37.352242  0.000008 -16.973642
# so           1  3.799825e-12 -37.937204  0.000005 -17.558604
# now          1  3.799825e-12 -37.937204  0.000005 -17.558604
# obliged      1  3.799825e-12 -37.937204  0.000005 -17.558604
# one          1  3.799825e-12 -37.937204  0.000005 -17.558604
# out          1  3.799825e-12 -37.937204  0.000005 -17.558604
# really       1  3.799825e-12 -37.937204  0.000005 -17.558604
# renewing     1  3.799825e-12 -37.937204  0.000005 -17.558604
# set          1  3.799825e-12 -37.937204  0.000005 -17.558604
# shewn        1  3.799825e-12 -37.937204  0.000005 -17.558604
# a            1  3.799825e-12 -37.937204  0.000005 -17.558604
# nineteen     1  3.799825e-12 -37.937204  0.000005 -17.558604
# still        1  3.799825e-12 -37.937204  0.000005 -17.558604
# sure         1  3.799825e-12 -37.937204  0.000005 -17.558604
# tenderness   1  3.799825e-12 -37.937204  0.000005 -17.558604
# the          1  3.799825e-12 -37.937204  0.000005 -17.558604
# to           1  3.799825e-12 -37.937204  0.000005 -17.558604
# too          1  3.799825e-12 -37.937204  0.000005 -17.558604
# walking      1  3.799825e-12 -37.937204  0.000005 -17.558604
# sporting     1  3.799825e-12 -37.937204  0.000005 -17.558604
# never        1  3.799825e-12 -37.937204  0.000005 -17.558604
# all          1  3.799825e-12 -37.937204  0.000005 -17.558604
# conscious    1  3.799825e-12 -37.937204  0.000005 -17.558604
# almost       1  3.799825e-12 -37.937204  0.000005 -17.558604
# already      1  3.799825e-12 -37.937204  0.000005 -17.558604
# among        1  3.799825e-12 -37.937204  0.000005 -17.558604
# amused       1  3.799825e-12 -37.937204  0.000005 -17.558604
# ashamed      1  3.799825e-12 -37.937204  0.000005 -17.558604
# astonished   1  3.799825e-12 -37.937204  0.000005 -17.558604
# caught       1  3.799825e-12 -37.937204  0.000005 -17.558604
# come         1  3.799825e-12 -37.937204  0.000005 -17.558604
# considering  1  3.799825e-12 -37.937204  0.000005 -17.558604
# much         1  3.799825e-12 -37.937204  0.000005 -17.558604
# delighted    1  3.799825e-12 -37.937204  0.000005 -17.558604
# enabled      1  3.799825e-12 -37.937204  0.000005 -17.558604
# her          1  3.799825e-12 -37.937204  0.000005 -17.558604
# improved     1  3.799825e-12 -37.937204  0.000005 -17.558604
# inevitable   1  3.799825e-12 -37.937204  0.000005 -17.558604
# left         1  3.799825e-12 -37.937204  0.000005 -17.558604
# mary         1  3.799825e-12 -37.937204  0.000005 -17.558604
# most         1  3.799825e-12 -37.937204  0.000005 -17.558604
# well         1  3.799825e-12 -37.937204  0.000005 -17.558604

# %%
PP1 = round(2**(-LM[0].log_p.sum() / len(LM[0])))
PP2 = round(2**(-LM[1].log_cp.sum() / len(LM[1])))
PP3 = round(2**(-LM[2].log_cp.sum() / len(LM[2])))

# %%
PP1, PP2, PP3
# Out:
# (47891, 12663, 27600)

# %% [markdown]
# # Collect Test Data

# %% [markdown]
# ## Choose Test Sentences

# %%
# Some paragraphs from Austen's _Emma_ and other stuff (first two)
S_TEST = """
The car was brand new
Computer programs are full of bugs
The event had every promise of happiness for her friend 
Mr Weston was a man of unexceptionable character easy fortune suitable age and pleasant manners
and there was some satisfaction in considering with what self-denying generous friendship she had always wished and promoted the match
but it was a black morning's work for her 
The want of Miss Taylor would be felt every hour of every day 
She recalled her past kindness the kindness the affection of sixteen years 
how she had taught and how she had played with her from five years old 
how she had devoted all her powers to attach and amuse her in health 
and how nursed her through the various illnesses of childhood 
A large debt of gratitude was owing here 
but the intercourse of the last seven years 
the equal footing and perfect unreserve which had soon followed Isabella's marriage 
on their being left to each other was yet a dearer tenderer recollection 
She had been a friend and companion such as few possessed intelligent well-informed useful gentle 
knowing all the ways of the family 
interested in all its concerns 
and peculiarly interested in herself in every pleasure every scheme of hers 
one to whom she could speak every thought as it arose 
and who had such an affection for her as could never find fault 
How was she to bear the change 
It was true that her friend was going only half a mile from them 
but Emma was aware that great must be the difference between a Mrs Weston 
only half a mile from them 
and a Miss Taylor in the house 
and with all her advantages natural and domestic 
she was now in great danger of suffering from intellectual solitude 
She dearly loved her father 
but he was no companion for her 
He could not meet her in conversation rational or playful 
The evil of the actual disparity in their ages
and Mr Woodhouse had not married early
was much increased by his constitution and habits 
for having been a valetudinarian all his life 
without activity of mind or body 
he was a much older man in ways than in years 
and though everywhere beloved for the friendliness of his heart and his amiable temper 
his talents could not have recommended him at any time 
Her sister though comparatively but little removed by matrimony 
being settled in London only sixteen miles off was much beyond her daily reach 
and many a long October and November evening must be struggled through at Hartfield 
before Christmas brought the next visit from Isabella and her husband 
and their little children to fill the house and give her pleasant society again 
""".split('\n')[1:-1]

# %%
test = NgramCounter(S_TEST, V_TRAIN)
test.generate()
model.predict(test)

# %%
round(test.I.w0.value_counts().loc['<UNK>'] / test.I.w0.value_counts().sum(), 2)
# Out:
# 0.07

# %% [markdown]
# ### Unigrams

# %%
test.S.sort_values('pp1')[['sent_str', 'pp1', 'pp2', 'pp3']].style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_f3a84_row0_col1,#T_f3a84_row0_col2,#T_f3a84_row0_col3,#T_f3a84_row1_col2,#T_f3a84_row1_col3,#T_f3a84_row3_col2,#T_f3a84_row3_col3,#T_f3a84_row4_col3,#T_f3a84_row5_col3,#T_f3a84_row7_col3,#T_f3a84_row9_col2,#T_f3a84_row9_col3,#T_f3a84_row12_col3,#T_f3a84_row19_col3,#T_f3a84_row20_col3{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_f3a84_row1_col1,#T_f3a84_row2_col2,#T_f3a84_row4_col2,#T_f3a84_row8_col3,#T_f3a84_row12_col2{
#             background-color:  #fef6fa;
#             color:  #000000;
#         }#T_f3a84_row2_col1,#T_f3a84_row5_col2,#T_f3a84_row15_col2,#T_f3a84_row17_col3,#T_f3a84_row31_col2{
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }#T_f3a84_row2_col3,#T_f3a84_row7_col2,#T_f3a84_row11_col3,#T_f3a84_row14_col3,#T_f3a84_row24_col2,#T_f3a84_row24_col3,#T_f3a84_row26_col3,#T_f3a84_row30_col2,#T_f3a84_row30_col3,#T_f3a84_row32_col3{
#             background-color:  #fef6fb;
#             color:  #000000;
#         }#T_f3a84_row3_col1,#T_f3a84_row4_col1,#T_f3a84_row23_col2{
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }#T_f3a84_row5_col1,#T_f3a84_row8_col2,#T_f3a84_row27_col2,#T_f3a84_row34_col3{
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }#T_f3a84_row6_col1{
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }#T_f3a84_row6_col2,#T_f3a84_row21_col2{
#             background-color:  #faf3f9;
#             color:  #000000;
#         }#T_f3a84_row6_col3,#T_f3a84_row18_col2,#T_f3a84_row25_col3{
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }#T_f3a84_row7_col1,#T_f3a84_row39_col2{
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }#T_f3a84_row8_col1,#T_f3a84_row36_col2{
#             background-color:  #e1dfed;
#             color:  #000000;
#         }#T_f3a84_row9_col1{
#             background-color:  #e0deed;
#             color:  #000000;
#         }#T_f3a84_row10_col1{
#             background-color:  #dad9ea;
#             color:  #000000;
#         }#T_f3a84_row10_col2,#T_f3a84_row15_col3{
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }#T_f3a84_row10_col3,#T_f3a84_row11_col2,#T_f3a84_row13_col2,#T_f3a84_row14_col2,#T_f3a84_row16_col3,#T_f3a84_row20_col2,#T_f3a84_row21_col3,#T_f3a84_row25_col2{
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }#T_f3a84_row11_col1{
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }#T_f3a84_row12_col1{
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }#T_f3a84_row13_col1{
#             background-color:  #ced0e6;
#             color:  #000000;
#         }#T_f3a84_row13_col3{
#             background-color:  #e4e1ef;
#             color:  #000000;
#         }#T_f3a84_row14_col1{
#             background-color:  #cccfe5;
#             color:  #000000;
#         }#T_f3a84_row15_col1,#T_f3a84_row16_col1{
#             background-color:  #c6cce3;
#             color:  #000000;
#         }#T_f3a84_row16_col2,#T_f3a84_row29_col2,#T_f3a84_row34_col2,#T_f3a84_row35_col2{
#             background-color:  #f5eff6;
#             color:  #000000;
#         }#T_f3a84_row17_col1{
#             background-color:  #c2cbe2;
#             color:  #000000;
#         }#T_f3a84_row17_col2,#T_f3a84_row19_col2,#T_f3a84_row32_col2{
#             background-color:  #faf2f8;
#             color:  #000000;
#         }#T_f3a84_row18_col1{
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }#T_f3a84_row18_col3{
#             background-color:  #efe9f3;
#             color:  #000000;
#         }#T_f3a84_row19_col1{
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }#T_f3a84_row20_col1,#T_f3a84_row21_col1{
#             background-color:  #b3c3de;
#             color:  #000000;
#         }#T_f3a84_row22_col1,#T_f3a84_row23_col1{
#             background-color:  #b0c2de;
#             color:  #000000;
#         }#T_f3a84_row22_col2{
#             background-color:  #ede7f2;
#             color:  #000000;
#         }#T_f3a84_row22_col3{
#             background-color:  #f3edf5;
#             color:  #000000;
#         }#T_f3a84_row23_col3,#T_f3a84_row28_col3{
#             background-color:  #eae6f1;
#             color:  #000000;
#         }#T_f3a84_row24_col1{
#             background-color:  #adc1dd;
#             color:  #000000;
#         }#T_f3a84_row25_col1{
#             background-color:  #acc0dd;
#             color:  #000000;
#         }#T_f3a84_row26_col1{
#             background-color:  #a5bddb;
#             color:  #000000;
#         }#T_f3a84_row26_col2,#T_f3a84_row31_col3,#T_f3a84_row35_col3{
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }#T_f3a84_row27_col1,#T_f3a84_row28_col1,#T_f3a84_row29_col1{
#             background-color:  #91b5d6;
#             color:  #000000;
#         }#T_f3a84_row27_col3,#T_f3a84_row28_col2,#T_f3a84_row29_col3{
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }#T_f3a84_row30_col1{
#             background-color:  #8cb3d5;
#             color:  #000000;
#         }#T_f3a84_row31_col1{
#             background-color:  #88b1d4;
#             color:  #000000;
#         }#T_f3a84_row32_col1{
#             background-color:  #6fa7ce;
#             color:  #000000;
#         }#T_f3a84_row33_col1,#T_f3a84_row34_col1{
#             background-color:  #69a5cc;
#             color:  #000000;
#         }#T_f3a84_row33_col2{
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }#T_f3a84_row33_col3{
#             background-color:  #60a1ca;
#             color:  #000000;
#         }#T_f3a84_row35_col1{
#             background-color:  #4496c3;
#             color:  #000000;
#         }#T_f3a84_row36_col1{
#             background-color:  #2182b9;
#             color:  #000000;
#         }#T_f3a84_row36_col3{
#             background-color:  #f5eef6;
#             color:  #000000;
#         }#T_f3a84_row37_col1{
#             background-color:  #0872b1;
#             color:  #f1f1f1;
#         }#T_f3a84_row37_col2{
#             background-color:  #c5cce3;
#             color:  #000000;
#         }#T_f3a84_row37_col3{
#             background-color:  #b1c2de;
#             color:  #000000;
#         }#T_f3a84_row38_col1{
#             background-color:  #05659f;
#             color:  #f1f1f1;
#         }#T_f3a84_row38_col2,#T_f3a84_row40_col2{
#             background-color:  #78abd0;
#             color:  #000000;
#         }#T_f3a84_row38_col3{
#             background-color:  #bcc7e1;
#             color:  #000000;
#         }#T_f3a84_row39_col1{
#             background-color:  #046299;
#             color:  #f1f1f1;
#         }#T_f3a84_row39_col3{
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }#T_f3a84_row40_col1{
#             background-color:  #045e94;
#             color:  #f1f1f1;
#         }#T_f3a84_row40_col3{
#             background-color:  #75a9cf;
#             color:  #000000;
#         }#T_f3a84_row41_col1{
#             background-color:  #034d79;
#             color:  #f1f1f1;
#         }#T_f3a84_row41_col2,#T_f3a84_row43_col1,#T_f3a84_row43_col3{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_f3a84_row41_col3{
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }#T_f3a84_row42_col1{
#             background-color:  #034973;
#             color:  #f1f1f1;
#         }#T_f3a84_row42_col2{
#             background-color:  #afc1dd;
#             color:  #000000;
#         }#T_f3a84_row42_col3{
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }#T_f3a84_row43_col2{
#             background-color:  #dedcec;
#             color:  #000000;
#         }</style><table id="T_f3a84_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sent_str</th>        <th class="col_heading level0 col1" >pp1</th>        <th class="col_heading level0 col2" >pp2</th>        <th class="col_heading level0 col3" >pp3</th>    </t

# %%
test.S.loc[1].sent_str
# Out:
# 'Computer programs are full of bugs'

# %%
test.S.loc[0].sent_str
# Out:
# 'The car was brand new'

# %% [markdown]
# ### Bigrams

# %%
test.S.sort_values('pp2')[['sent_str', 'pp1', 'pp2', 'pp3']].style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_7616c_row0_col1,#T_7616c_row7_col2,#T_7616c_row8_col2,#T_7616c_row9_col2,#T_7616c_row33_col3{
#             background-color:  #fef6fa;
#             color:  #000000;
#         }#T_7616c_row0_col2,#T_7616c_row0_col3,#T_7616c_row1_col1,#T_7616c_row1_col2,#T_7616c_row1_col3,#T_7616c_row2_col2,#T_7616c_row2_col3,#T_7616c_row3_col2,#T_7616c_row3_col3,#T_7616c_row4_col3,#T_7616c_row7_col3,#T_7616c_row8_col3,#T_7616c_row11_col3,#T_7616c_row19_col3,#T_7616c_row26_col3{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_7616c_row2_col1{
#             background-color:  #e0deed;
#             color:  #000000;
#         }#T_7616c_row3_col1,#T_7616c_row7_col1,#T_7616c_row31_col2{
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }#T_7616c_row4_col1,#T_7616c_row36_col2{
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }#T_7616c_row4_col2,#T_7616c_row5_col2,#T_7616c_row5_col3,#T_7616c_row6_col2,#T_7616c_row6_col3,#T_7616c_row9_col3,#T_7616c_row10_col3,#T_7616c_row12_col3,#T_7616c_row16_col3,#T_7616c_row20_col3{
#             background-color:  #fef6fb;
#             color:  #000000;
#         }#T_7616c_row5_col1{
#             background-color:  #adc1dd;
#             color:  #000000;
#         }#T_7616c_row6_col1{
#             background-color:  #8cb3d5;
#             color:  #000000;
#         }#T_7616c_row8_col1{
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }#T_7616c_row9_col1,#T_7616c_row21_col3,#T_7616c_row24_col2,#T_7616c_row25_col2,#T_7616c_row26_col2{
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }#T_7616c_row10_col1{
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }#T_7616c_row10_col2,#T_7616c_row11_col2,#T_7616c_row12_col2,#T_7616c_row13_col2,#T_7616c_row14_col2,#T_7616c_row17_col3,#T_7616c_row22_col3,#T_7616c_row29_col3{
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }#T_7616c_row11_col1,#T_7616c_row17_col1{
#             background-color:  #b3c3de;
#             color:  #000000;
#         }#T_7616c_row12_col1{
#             background-color:  #cccfe5;
#             color:  #000000;
#         }#T_7616c_row13_col1{
#             background-color:  #acc0dd;
#             color:  #000000;
#         }#T_7616c_row13_col3,#T_7616c_row15_col2,#T_7616c_row18_col3{
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }#T_7616c_row14_col1{
#             background-color:  #ced0e6;
#             color:  #000000;
#         }#T_7616c_row14_col3{
#             background-color:  #e4e1ef;
#             color:  #000000;
#         }#T_7616c_row15_col1{
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }#T_7616c_row15_col3{
#             background-color:  #efe9f3;
#             color:  #000000;
#         }#T_7616c_row16_col1{
#             background-color:  #a5bddb;
#             color:  #000000;
#         }#T_7616c_row16_col2,#T_7616c_row25_col3,#T_7616c_row30_col3{
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }#T_7616c_row17_col2,#T_7616c_row18_col2{
#             background-color:  #faf3f9;
#             color:  #000000;
#         }#T_7616c_row18_col1{
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }#T_7616c_row19_col1{
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }#T_7616c_row19_col2,#T_7616c_row20_col2,#T_7616c_row21_col2{
#             background-color:  #faf2f8;
#             color:  #000000;
#         }#T_7616c_row20_col1{
#             background-color:  #6fa7ce;
#             color:  #000000;
#         }#T_7616c_row21_col1{
#             background-color:  #c2cbe2;
#             color:  #000000;
#         }#T_7616c_row22_col1{
#             background-color:  #dad9ea;
#             color:  #000000;
#         }#T_7616c_row22_col2,#T_7616c_row24_col3{
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }#T_7616c_row23_col1,#T_7616c_row28_col1,#T_7616c_row34_col1{
#             background-color:  #91b5d6;
#             color:  #000000;
#         }#T_7616c_row23_col2,#T_7616c_row28_col3,#T_7616c_row34_col3{
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }#T_7616c_row23_col3,#T_7616c_row31_col3{
#             background-color:  #eae6f1;
#             color:  #000000;
#         }#T_7616c_row24_col1,#T_7616c_row29_col1{
#             background-color:  #c6cce3;
#             color:  #000000;
#         }#T_7616c_row25_col1{
#             background-color:  #88b1d4;
#             color:  #000000;
#         }#T_7616c_row26_col1,#T_7616c_row27_col3,#T_7616c_row33_col2,#T_7616c_row34_col2{
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }#T_7616c_row27_col1,#T_7616c_row35_col1{
#             background-color:  #69a5cc;
#             color:  #000000;
#         }#T_7616c_row27_col2,#T_7616c_row28_col2,#T_7616c_row29_col2,#T_7616c_row30_col2{
#             background-color:  #f5eff6;
#             color:  #000000;
#         }#T_7616c_row30_col1{
#             background-color:  #4496c3;
#             color:  #000000;
#         }#T_7616c_row31_col1,#T_7616c_row32_col1{
#             background-color:  #b0c2de;
#             color:  #000000;
#         }#T_7616c_row32_col2{
#             background-color:  #ede7f2;
#             color:  #000000;
#         }#T_7616c_row32_col3{
#             background-color:  #f3edf5;
#             color:  #000000;
#         }#T_7616c_row33_col1,#T_7616c_row37_col2{
#             background-color:  #e1dfed;
#             color:  #000000;
#         }#T_7616c_row35_col2{
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }#T_7616c_row35_col3{
#             background-color:  #60a1ca;
#             color:  #000000;
#         }#T_7616c_row36_col1{
#             background-color:  #046299;
#             color:  #f1f1f1;
#         }#T_7616c_row36_col3{
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }#T_7616c_row37_col1{
#             background-color:  #2182b9;
#             color:  #000000;
#         }#T_7616c_row37_col3{
#             background-color:  #f5eef6;
#             color:  #000000;
#         }#T_7616c_row38_col1,#T_7616c_row38_col3,#T_7616c_row43_col2{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_7616c_row38_col2{
#             background-color:  #dedcec;
#             color:  #000000;
#         }#T_7616c_row39_col1{
#             background-color:  #0872b1;
#             color:  #f1f1f1;
#         }#T_7616c_row39_col2{
#             background-color:  #c5cce3;
#             color:  #000000;
#         }#T_7616c_row39_col3{
#             background-color:  #b1c2de;
#             color:  #000000;
#         }#T_7616c_row40_col1{
#             background-color:  #034973;
#             color:  #f1f1f1;
#         }#T_7616c_row40_col2{
#             background-color:  #afc1dd;
#             color:  #000000;
#         }#T_7616c_row40_col3{
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }#T_7616c_row41_col1{
#             background-color:  #045e94;
#             color:  #f1f1f1;
#         }#T_7616c_row41_col2,#T_7616c_row42_col2{
#             background-color:  #78abd0;
#             color:  #000000;
#         }#T_7616c_row41_col3{
#             background-color:  #75a9cf;
#             color:  #000000;
#         }#T_7616c_row42_col1{
#             background-color:  #05659f;
#             color:  #f1f1f1;
#         }#T_7616c_row42_col3{
#             background-color:  #bcc7e1;
#             color:  #000000;
#         }#T_7616c_row43_col1{
#             background-color:  #034d79;
#             color:  #f1f1f1;
#         }#T_7616c_row43_col3{
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }</style><table id="T_7616c_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sent_str</th>        <th class="col_heading level0 col1" >pp1</th>        <th class="col_heading level0 col2" >pp2</th>        <th class="col_heading level0 col3" >pp3</th>    </t

# %% [markdown]
# ### Trigrams

# %%
test.S.sort_values('pp3')[['sent_str', 'pp1', 'pp2', 'pp3']].style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_27941_row0_col1{
#             background-color:  #e0deed;
#             color:  #000000;
#         }#T_27941_row0_col2,#T_27941_row0_col3,#T_27941_row1_col2,#T_27941_row1_col3,#T_27941_row2_col2,#T_27941_row2_col3,#T_27941_row3_col3,#T_27941_row4_col3,#T_27941_row5_col1,#T_27941_row5_col2,#T_27941_row5_col3,#T_27941_row6_col3,#T_27941_row7_col3,#T_27941_row8_col3,#T_27941_row9_col3{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_27941_row1_col1,#T_27941_row7_col2,#T_27941_row8_col2,#T_27941_row10_col2,#T_27941_row17_col3{
#             background-color:  #fef6fa;
#             color:  #000000;
#         }#T_27941_row2_col1,#T_27941_row8_col1,#T_27941_row32_col2{
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }#T_27941_row3_col1,#T_27941_row37_col2{
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }#T_27941_row3_col2,#T_27941_row10_col3,#T_27941_row11_col3,#T_27941_row12_col3,#T_27941_row13_col3,#T_27941_row14_col2,#T_27941_row14_col3,#T_27941_row15_col2,#T_27941_row15_col3,#T_27941_row16_col3{
#             background-color:  #fef6fb;
#             color:  #000000;
#         }#T_27941_row4_col1,#T_27941_row17_col2,#T_27941_row27_col2,#T_27941_row34_col3{
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }#T_27941_row4_col2,#T_27941_row10_col1,#T_27941_row24_col2,#T_27941_row25_col2,#T_27941_row28_col3{
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }#T_27941_row6_col1{
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }#T_27941_row6_col2,#T_27941_row13_col2,#T_27941_row28_col2{
#             background-color:  #faf2f8;
#             color:  #000000;
#         }#T_27941_row7_col1{
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }#T_27941_row9_col1,#T_27941_row18_col1{
#             background-color:  #b3c3de;
#             color:  #000000;
#         }#T_27941_row9_col2,#T_27941_row11_col2,#T_27941_row16_col2,#T_27941_row18_col3,#T_27941_row19_col3,#T_27941_row20_col3,#T_27941_row22_col2,#T_27941_row35_col2{
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }#T_27941_row11_col1{
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }#T_27941_row12_col1{
#             background-color:  #a5bddb;
#             color:  #000000;
#         }#T_27941_row12_col2,#T_27941_row23_col3,#T_27941_row24_col3{
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }#T_27941_row13_col1{
#             background-color:  #6fa7ce;
#             color:  #000000;
#         }#T_27941_row14_col1{
#             background-color:  #8cb3d5;
#             color:  #000000;
#         }#T_27941_row15_col1{
#             background-color:  #adc1dd;
#             color:  #000000;
#         }#T_27941_row16_col1{
#             background-color:  #cccfe5;
#             color:  #000000;
#         }#T_27941_row17_col1,#T_27941_row29_col2{
#             background-color:  #e1dfed;
#             color:  #000000;
#         }#T_27941_row18_col2,#T_27941_row21_col2{
#             background-color:  #faf3f9;
#             color:  #000000;
#         }#T_27941_row19_col1{
#             background-color:  #dad9ea;
#             color:  #000000;
#         }#T_27941_row19_col2,#T_27941_row25_col3{
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }#T_27941_row20_col1,#T_27941_row25_col1{
#             background-color:  #c6cce3;
#             color:  #000000;
#         }#T_27941_row20_col2,#T_27941_row23_col2,#T_27941_row26_col2,#T_27941_row34_col2{
#             background-color:  #f5eff6;
#             color:  #000000;
#         }#T_27941_row21_col1{
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }#T_27941_row21_col3,#T_27941_row22_col3,#T_27941_row31_col2{
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }#T_27941_row22_col1{
#             background-color:  #acc0dd;
#             color:  #000000;
#         }#T_27941_row23_col1{
#             background-color:  #4496c3;
#             color:  #000000;
#         }#T_27941_row24_col1{
#             background-color:  #88b1d4;
#             color:  #000000;
#         }#T_27941_row26_col1,#T_27941_row27_col1,#T_27941_row33_col1{
#             background-color:  #91b5d6;
#             color:  #000000;
#         }#T_27941_row26_col3,#T_27941_row27_col3,#T_27941_row33_col2{
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }#T_27941_row28_col1{
#             background-color:  #c2cbe2;
#             color:  #000000;
#         }#T_27941_row29_col1{
#             background-color:  #2182b9;
#             color:  #000000;
#         }#T_27941_row29_col3{
#             background-color:  #f5eef6;
#             color:  #000000;
#         }#T_27941_row30_col1,#T_27941_row32_col1{
#             background-color:  #b0c2de;
#             color:  #000000;
#         }#T_27941_row30_col2{
#             background-color:  #ede7f2;
#             color:  #000000;
#         }#T_27941_row30_col3{
#             background-color:  #f3edf5;
#             color:  #000000;
#         }#T_27941_row31_col1{
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }#T_27941_row31_col3{
#             background-color:  #efe9f3;
#             color:  #000000;
#         }#T_27941_row32_col3,#T_27941_row33_col3{
#             background-color:  #eae6f1;
#             color:  #000000;
#         }#T_27941_row34_col1,#T_27941_row42_col1{
#             background-color:  #69a5cc;
#             color:  #000000;
#         }#T_27941_row35_col1{
#             background-color:  #ced0e6;
#             color:  #000000;
#         }#T_27941_row35_col3{
#             background-color:  #e4e1ef;
#             color:  #000000;
#         }#T_27941_row36_col1{
#             background-color:  #034973;
#             color:  #f1f1f1;
#         }#T_27941_row36_col2{
#             background-color:  #afc1dd;
#             color:  #000000;
#         }#T_27941_row36_col3{
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }#T_27941_row37_col1{
#             background-color:  #046299;
#             color:  #f1f1f1;
#         }#T_27941_row37_col3{
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }#T_27941_row38_col1{
#             background-color:  #034d79;
#             color:  #f1f1f1;
#         }#T_27941_row38_col2,#T_27941_row43_col1,#T_27941_row43_col3{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_27941_row38_col3{
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }#T_27941_row39_col1{
#             background-color:  #05659f;
#             color:  #f1f1f1;
#         }#T_27941_row39_col2,#T_27941_row41_col2{
#             background-color:  #78abd0;
#             color:  #000000;
#         }#T_27941_row39_col3{
#             background-color:  #bcc7e1;
#             color:  #000000;
#         }#T_27941_row40_col1{
#             background-color:  #0872b1;
#             color:  #f1f1f1;
#         }#T_27941_row40_col2{
#             background-color:  #c5cce3;
#             color:  #000000;
#         }#T_27941_row40_col3{
#             background-color:  #b1c2de;
#             color:  #000000;
#         }#T_27941_row41_col1{
#             background-color:  #045e94;
#             color:  #f1f1f1;
#         }#T_27941_row41_col3{
#             background-color:  #75a9cf;
#             color:  #000000;
#         }#T_27941_row42_col2{
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }#T_27941_row42_col3{
#             background-color:  #60a1ca;
#             color:  #000000;
#         }#T_27941_row43_col2{
#             background-color:  #dedcec;
#             color:  #000000;
#         }</style><table id="T_27941_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sent_str</th>        <th class="col_heading level0 col1" >pp1</th>        <th class="col_heading level0 col2" >pp2</th>        <th class="col_heading level0 col3" >pp3</th>    </t

# %%
test.S.reset_index().set_index('sent_str').pp3.sort_values(ascending=False).plot.barh(figsize=(5,15));

# %% [markdown]
# # Generate Text

# %%
LM[2].sort_values('cp')
# Out:
#                              n             p      log_p            cp  \
# w0    w1        w2
# <s>   <s>       therefore    1  3.799825e-12 -37.937204  1.824762e-08
#                 intimately   1  3.799825e-12 -37.937204  1.824762e-08
#                 interposed   1  3.799825e-12 -37.937204  1.824762e-08
#                 insisted     1  3.799825e-12 -37.937204  1.824762e-08
#                 infirmity    1  3.799825e-12 -37.937204  1.824762e-08
# ...                         ..           ...        ...           ...
# was   beginning to           8  1.709921e-11 -35.767279  1.243211e-04
# about </s>      <s>          8  1.709921e-11 -35.767279  1.243211e-04
# two   or        three       17  3.419842e-11 -34.767279  1.243211e-04
# home  </s>      <s>         35  6.839684e-11 -33.767279  1.243211e-04
# doing </s>      <s>          8  1.709921e-11 -35.767279  1.243211e-04
#
#                                log_cp
# w0    w1        w2
# <s>   <s>       therefore  -25.707716
#                 intimately -25.707716
#                 interposed -25.707716
#                 insisted   -25.707716
#                 infirmity  -25.707716
# ...                               ...
# was   beginning to         -12.973642
# about </s>      <s>        -12.973642
# two   or        three      -12.973642
# home  </s>      <s>        -12.973642
# doing </s>      <s>        -12.973642
#
# [160317 rows x 5 columns]

# %%
LM[2].loc[('<s>','<s>')]
# Out:
#               n             p      log_p            cp     log_cp
# w2
# <UNK>         5  1.139947e-11 -36.352242  5.474287e-08 -24.122754
# a           153  2.925865e-10 -31.670418  1.405067e-06 -19.440930
# about        10  2.089904e-11 -35.477773  1.003619e-07 -23.248285
# absence       1  3.799825e-12 -37.937204  1.824762e-08 -25.707716
# absolutely    1  3.799825e-12 -37.937204  1.824762e-08 -25.707716
# ...         ...           ...        ...           ...        ...
# you         254  4.844776e-10 -30.942851  2.326572e-06 -18.713363
# young         1  3.799825e-12 -37.937204  1.824762e-08 -25.707716
# younger       2  5.699737e-12 -37.352242  2.737143e-08 -25.122754
# your         59  1.139947e-10 -33.030314  5.474287e-07 -20.800826
# yours         1  3.799825e-12 -37.937204  1.824762e-08 -25.707716
#
# [667 rows x 5 columns]

# %%
def generate_text(LM, n=20):
    
    # Start with beginning sentence marker
    words = ['<s>', '<s>']
        
    # Sentence counter
    sent_count = 0
    
    while sent_count < n:
        
        # Get trigram context
        bg = tuple(words[-2:])

        # Get next word
        words.append(LM[2].loc[bg].sample(weights='cp').index.values[0])

        # Terminate when end-of-sentence marker found
        if words[-1] == '</s>':
            sent_count += 1                        
            if sent_count < n:
                words.append('<s>')
    
    # Create text from words
    text = ' '.join(words)
    
    sents = pd.DataFrame(dict(sent_str=text.split('<s> <s>')))
    sents['len'] = sents.sent_str.str.len()
    sents = sents[sents.len > 0]
    sents.sent_str = sents.sent_str.str.replace('<s> ', '')
    sents.sent_str = sents.sent_str.str.replace(' </s>', '')
    sents.sent_str = sents.sent_str.str.strip()
    sents.sent_str = sents.sent_str.str.replace(r" s ", "'s ", regex=True)
    sents['html'] = "<li>" + sents.sent_str.str.upper() + ".</li>"

    output = sents.sort_values('len').html.str.cat(sep='\n')
            
    display(HTML(f"<ol style='font-family:monospace;margin-left:1rem;width:4in;'>{output}</ol>"))
    
    return sents

# %%
sents = generate_text(LM, n=20)
# Out:
# <ol style='font-family:monospace;margin-left:1rem;width:4in;'><li>OH OH.</li>
# <li>COLONEL.</li>
# <li>CRIED MR.</li>
# <li>HIS EMOTION.</li>
# <li>THEY WERE TO LIVE.</li>
# <li>ROSE AT EXETER EXCHANGE.</li>
# <li>I GAVE HIM EVERY DAY MRS.</li>
# <li>BUT SIR JOHN WILL NOT BE SETTLED ANY WEEK.</li>
# <li>CONTINUED LUCY AFTER WIPING HER EYES BRIGHTENING.</li>
# <li>WAS IT MY DUTY TO CLEAR AWAY THE NOTION OF PEOPLE.</li>
# <li>SHE BOLDLY ACKNOWLEDGED HERSELF FLATTERED AND CONTINUED TO READ.</li>
# <li>HIS TONE HIS EXPRESSIONS AND STILL WITHOUT FORFEITING HER EXPECTATION.</li>
# <li>NOTHING COULD EXCEED HIS SOLICITUDE AND CARE AND MENTIONING HIM IN SOME CONFUSION.</li>
# <li>THEY ARE NOT WHAT I FELT WOULD BE THE COUNSELLOR OF HER STEPPING FORWARD IN THE SAME TIME WISHED TO DO GOOD BY.</li>
# <li>THE MINUTIAE OF DISTRESS AND ANNE FELT TRULY OBLIGED TO GIVE HIM THAT LIKE ALL OTHER QUALITIES OF THE DASHWOODS STAY.</li>
# <li>AND WHY SHOULD YOU IMAGINE I SUPPOSE THAT AT PRESENT IF I SHOULD BE LOSING MISS ANNE SEEMS BENT ON IT THAT IF IN CONSEQUENCE.</li>
# <li>BUT FOR MY SILENCE BECAUSE I KNOW THE SIGHT OF HIM TO GIVE SEDATENESS TO HER SOON AFTERWARDS HE FELL INTO A SCHEME WORTHY OF MRS.</li>
# <li>BY HIS BROTHER AND SISTER AND HER CHILD COULD BE CONTINUED WITHOUT THE EXERTION OF ALL THESE ALTERATIONS COULD BE COMING AND THE ADMIRAL GOUTY.</li>
# <li>IT IS PROBABLE THAT SOMETHING WOULD OCCUR IN YOUR MANNER MIGHT NOT APPROVE IN SPITE OF THEIR EMPLOYMENTS CONVERSATION WAS ALWAYS ANXIOUS TO MORTIFY.</li>
# <li>FOR THEIR SAKES AVOID A BREACH WITH THEIR COUNSEL OR THEIR CONVERSATION VERY MUCH GRATIFIED BY THIS AS SHE WANDERED ALONE BEFORE THE GATES OF DELAFORD NOW JUST MOUNTED AND BROUGHT THE WHOLE SOUL AND BEAMED IN THE MASS.</li></ol>

# %% [markdown]
# # Save

# %%
path_prefix = f"{data_home}/output/austen-combo"
HAPAX.to_csv(f"{path_prefix}-HAPAX.csv")
pd.Series(UNK).to_csv(f"{path_prefix}-UNK.txt", 'w')
for n in range(1, ngram_size):
    LM[n].to_csv(f"{path_prefix}-LM{n}.csv")

# %% [markdown]
# # Appendix
#
# ## Handling Missing Ngrams
#
# * Seen ngram: $ \frac{c + k}{N + Bk} $
# * Unseen ngram with seen context: $ \frac{k}{N + Bk} $
# * Unseen ngram with unseen context: $ \frac{k}{Bk} \rightarrow \frac{1}{B} $
# * Unknown Unigrams: `<UNK>`

# %% [markdown]
# ## Effective Counts
#
# $ (c_i + \alpha) \frac{M}{M + V\alpha} $

# %% [markdown]
# ## Perplexity
#
# $ PP(w) = 2^{-\frac{\ell(w)}{M}} $
#
# $ \ell(w) = i(w) $
#
# $ PP(w) = 2^{\frac{i(w)}{M}} $
