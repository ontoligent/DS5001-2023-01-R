# %% [markdown]
# # Metadata
#
# ```yaml
# Course:  DS 5001
# Module:  03 Lab
# Topic:   Inferring Language Models
# Version: 2
# Author:  R.C. Alvarado
# Date:    22 January 2022 (modified)
# ```
#
# **Purpose**:
#
# We create a series of word-level langage models from a set of novels and
# evaluate them.
#
# This notebook uses classes.

# %% [markdown]
# # Set Up

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np
import re
import seaborn as sns
from IPython.core.display import HTML

# %%
sns.set()

# %% [markdown]
# ## Configure

# %%
data_home = '../data'

# %%
OHCO = ['book_id', 'chap_num', 'para_num', 'sent_num', 'token_num']
text_file = f'{data_home}/output/austen-combo.csv'

# %% [markdown]
# # Import Data
#
# Problem: These texts treat Mr. and Mrs. as sentences. Since sentence breaks are represented in the OHCO, to fix this requires reparsing the source text into the TOKEN table with the abbreviation periods removed.

# %% [markdown]
# # Create Text Object

# %%
class Corpus():
    """Expects to have a tokenized text dataframe with OHCO as input."""
    
    TOKENS:pd.DataFrame # Expects to  have and OHCO index and token_str and term_str as columns
    VOCAB:pd.DataFrame # To be extracted from TOKENS
    
    def __init__(self, TOKENS:[]):
        self.TOKENS = TOKENS
        self.OHCO = TOKENS.index.names
        self.N = len(self.TOKENS)
        
    def extract_vocab(self):
        self.VOCAB = self.TOKENS.term_str.value_counts().to_frame('n').sort_index()
        self.VOCAB.index.name = 'term_str'
        self.VOCAB['n_chars'] = self.VOCAB.index.str.len()
        self.VOCAB['p'] = self.VOCAB.n / self.VOCAB.n.sum()
        self.VOCAB['i'] = np.log2(1/self.VOCAB.p)
        self.VOCAB['h'] = self.VOCAB.p * self.VOCAB.i
        self.H = self.VOCAB.h.sum()
        self.R = 1 - self.H / np.log2(len(self.VOCAB)) # H_max = log2(|V|)
        
    def extract_hapax_data(self):
        """Anticipating the language model, we find single instance words (hapaxes) and 
        describe them by charater length. We replace long and short hapaxes in this
        set with the value UNK since these have the most suprise."""
        
        # Create table of word lengths for all hapaxes
        self.hapaxes = self.VOCAB.query("n == 1").n_chars.value_counts().to_frame('n').sort_index() 
        self.hapaxes.index.name = 'n_chars'
        
        # Add prob features
        self.hapaxes['p'] = self.hapaxes.n / self.hapaxes.n.sum()
        self.hapaxes['s'] = 1 / self.hapaxes.p
        self.hapaxes['i'] = np.log2(self.hapaxes.s)
        self.hapaxes['h'] = self.hapaxes.p * self.hapaxes.i
        
        # Use prob features to select UNKs
        s_thresh = self.hapaxes.s.mean() # Could use quantiles ...
        unk_list = self.hapaxes[self.hapaxes.s > s_thresh].index.to_list()
        self.UNK = self.VOCAB[self.VOCAB.n_chars.isin(unk_list) & (self.VOCAB.n == 1)].index.to_list()

# %%
TOKENS = pd.read_csv(text_file).set_index(OHCO).dropna()
TOKENS['term_str'] = TOKENS.token_str.str.lower().str.replace(r'[\W_]+', '', regex=True)
TOKENS = TOKENS[TOKENS.term_str != '']

# %%
training_corpus = Corpus(TOKENS)
training_corpus.extract_vocab()
training_corpus.extract_hapax_data()

# %%
training_corpus.hapaxes.style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_e107d_row0_col0,#T_e107d_row0_col1,#T_e107d_row4_col2,#T_e107d_row10_col2{
#             background-color:  #fef6fb;
#             color:  #000000;
#         }#T_e107d_row0_col2{
#             background-color:  #75a9cf;
#             color:  #000000;
#         }#T_e107d_row0_col3{
#             background-color:  #045b8f;
#             color:  #f1f1f1;
#         }#T_e107d_row0_col4,#T_e107d_row3_col2,#T_e107d_row11_col2{
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }#T_e107d_row1_col0,#T_e107d_row1_col1,#T_e107d_row8_col3{
#             background-color:  #fef6fa;
#             color:  #000000;
#         }#T_e107d_row1_col2{
#             background-color:  #a8bedc;
#             color:  #000000;
#         }#T_e107d_row1_col3{
#             background-color:  #0566a0;
#             color:  #f1f1f1;
#         }#T_e107d_row1_col4{
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }#T_e107d_row2_col0,#T_e107d_row2_col1,#T_e107d_row14_col4{
#             background-color:  #f5eef6;
#             color:  #000000;
#         }#T_e107d_row2_col2{
#             background-color:  #f3edf5;
#             color:  #000000;
#         }#T_e107d_row2_col3{
#             background-color:  #6da6cd;
#             color:  #000000;
#         }#T_e107d_row2_col4{
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }#T_e107d_row3_col0,#T_e107d_row3_col1{
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }#T_e107d_row3_col3{
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }#T_e107d_row3_col4{
#             background-color:  #73a9cf;
#             color:  #000000;
#         }#T_e107d_row4_col0,#T_e107d_row4_col1{
#             background-color:  #3d93c2;
#             color:  #000000;
#         }#T_e107d_row4_col3{
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }#T_e107d_row4_col4{
#             background-color:  #056caa;
#             color:  #f1f1f1;
#         }#T_e107d_row5_col0,#T_e107d_row5_col1{
#             background-color:  #046299;
#             color:  #f1f1f1;
#         }#T_e107d_row5_col2,#T_e107d_row6_col2,#T_e107d_row6_col3,#T_e107d_row7_col2,#T_e107d_row7_col3,#T_e107d_row8_col2,#T_e107d_row9_col2,#T_e107d_row15_col0,#T_e107d_row15_col1,#T_e107d_row15_col4,#T_e107d_row16_col0,#T_e107d_row16_col1,#T_e107d_row16_col4{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_e107d_row5_col3{
#             background-color:  #faf2f8;
#             color:  #000000;
#         }#T_e107d_row5_col4{
#             background-color:  #034f7d;
#             color:  #f1f1f1;
#         }#T_e107d_row6_col0,#T_e107d_row6_col1,#T_e107d_row6_col4,#T_e107d_row7_col0,#T_e107d_row7_col1,#T_e107d_row7_col4,#T_e107d_row15_col2,#T_e107d_row15_col3,#T_e107d_row16_col2,#T_e107d_row16_col3{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_e107d_row8_col0,#T_e107d_row8_col1{
#             background-color:  #03476f;
#             color:  #f1f1f1;
#         }#T_e107d_row8_col4{
#             background-color:  #023f64;
#             color:  #f1f1f1;
#         }#T_e107d_row9_col0,#T_e107d_row9_col1{
#             background-color:  #348ebf;
#             color:  #000000;
#         }#T_e107d_row9_col3{
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }#T_e107d_row9_col4{
#             background-color:  #056aa6;
#             color:  #f1f1f1;
#         }#T_e107d_row10_col0,#T_e107d_row10_col1,#T_e107d_row11_col4{
#             background-color:  #78abd0;
#             color:  #000000;
#         }#T_e107d_row10_col3{
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }#T_e107d_row10_col4{
#             background-color:  #2484ba;
#             color:  #000000;
#         }#T_e107d_row11_col0,#T_e107d_row11_col1{
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }#T_e107d_row11_col3{
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }#T_e107d_row12_col0,#T_e107d_row12_col1{
#             background-color:  #ece7f2;
#             color:  #000000;
#         }#T_e107d_row12_col2{
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }#T_e107d_row12_col3{
#             background-color:  #9ebad9;
#             color:  #000000;
#         }#T_e107d_row12_col4{
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }#T_e107d_row13_col0,#T_e107d_row13_col1{
#             background-color:  #f5eff6;
#             color:  #000000;
#         }#T_e107d_row13_col2{
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }#T_e107d_row13_col3{
#             background-color:  #67a4cc;
#             color:  #000000;
#         }#T_e107d_row13_col4{
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }#T_e107d_row14_col0,#T_e107d_row14_col1{
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }#T_e107d_row14_col2{
#             background-color:  #dddbec;
#             color:  #000000;
#         }#T_e107d_row14_col3{
#             background-color:  #2081b9;
#             color:  #000000;
#         }</style><table id="T_e107d_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >n</th>        <th class="col_heading level0 col1" >p</th>        <th class="col_heading level0 col2" >s</th>        <th class="col_heading level0 col3" >i</th>        <th class="col_heading level0 col4" >h</th>    </tr>    <tr>        <th class="index_name level0" >n_chars</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e107d_level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_e107d_row0_col0" class="data row0 col0" >6</td>
#                         <td id="T_e107d_row0_col1" class="data row0 col1" >0.001935</td>
#                         <td id="T_e107d_row0_col2" class="data row0 col2" >516.833333</td>
#                         <td id="T_e107d_row0_col3" class="data row0 col3" >9.013555</td>
#                         <td id="T_e107d_row0_col4" class="data row0 col4" >0.017440</td>
#             </tr>
#             <tr>
#                         <th id="T_e107d_level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_e107d_row1_col0" class="data row1 col0" >8</td>
#                         <td id="T_e107d_row1_col1" class="data row1 col1" >0.002580</td>
#                         <td id="T_e107d_row1_col2" class="data row1 col2" >387.625000</td>
#                         <td id="T_e107d_row1_col3" class="data row1 col3" >8.598518</td>
#                         <td id="T_e107d_row1_col4" class="data row1 col4" >0.022183</td>
#             </tr>
#             <tr>
#                         <th id="T_e107d_level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_e107d_row2_col0" class="data row2 col0" >35</td>
#                         <td id="T_e107d_row2_col1" class="data row2 col1" >0.011287</td>
#                         <td id="T_e107d_row2_col2" class="data row2 col2" >88.600000</td>
#                         <td id="T_e107d_row2_col3" class="data row2 col3" >6.469235</td>
#                         <td id="T_e107d_row2_col4" class="data row2 col4" >0.073016</td>
#             </tr>
#             <tr>
#                         <th id="T_e107d_level0_row3" class="row_heading level0 row3" >4</th>
#                         <td id="T_e107d_row3_col0" class="data row3 col0" >152</td>
#                         <td id="T_e107d_row3_col1" class="data row3 col1" >0.049016</td>
#                         <td id="T_e107d_row3_col2" class="data row3 col2" >20.401316</td>
#                         <td id="T_e107d_row3_col3" class="data row3 col3" >4.350590</td>
#                         <td id="T_e107d_row3_col4" class="data row3 col4" >0.213250</t

# %% [markdown]
# # Create Models

# %%
class NgramModel():
    """Generate an n-gram model of lenght 1 to 3 from a list of tokens. 
    Expects a Corpus object containing a valid TOKENS dataframe. Will generate
    a language model at the level specificed as well as all lower level models."""
    
    sent_mark = '<s>', '</s>'
    unknown_term = '<UNK>'
    unknown_thresh = 1
    
    def __init__(self, CORPUS:Corpus, w:int = 3, unk_list:str=[]):
        self.CORPUS = CORPUS
        self.OHCO = list(CORPUS.TOKENS.index.names)
        self.w = w # Shlould check if in range
        self.unk_list = unk_list
        
    def make_index(self):
        """Generate all n-length combos (with values)"""
        
        print('Converting tokens to list of sentences ...')
        S = self.CORPUS.TOKENS.groupby(self.OHCO[:-1]).term_str\
            .apply(lambda x: x.str.cat(sep=' '))
        self.n_sents = len(S)
        
        print('Converting sentences to tokens with special tokens ...')
        self.K = S.apply(lambda x: pd.Series([self.sent_mark[0]] + x.split() + [self.sent_mark[1]]))\
            .stack().to_frame('term_str').reset_index(drop=True)
        self.n_tokens = len(self.K)
                
        print('Replacing rare words with UNK ...') # Should this happen here?
        self.K.loc[self.K.term_str.isin(self.unk_list), 'term_str'] = self.unknown_term
                
        print('Creating ngrams from offset lists ...')
        self.NG = pd.concat([self.K.shift(-i).term_str for i in range(self.w)], axis=1)
        self.widx = [f'w{i}' for i in range(self.w)]
        self.NG.columns = self.widx
                    
    def make_model(self):
        
        # A dictionary to store our models. 
        # We use a dict, not a list, to have 1-based indexing.
        self.M = {} 
        
        # Create models
        for i in range(self.w):
            level = self.w - i # We go backwards so we can get slices from the widx list
            print(f"Creating {level}-gram model ...")
            self.M[level] = self.NG.value_counts(self.widx[:level]).to_frame('n').sort_index()
             
        # Replace low-freq ngrams with UNKs ...
        for level in range(2, self.w + 1):
            print(f"Getting lo freqs for level {level}")
            unk_key = tuple(self.unknown_term for _ in range(level))
            self.M[level].loc[unk_key, 'n'] = self.M[level].query("n == 1").shape[0]
#             self.M[level] = self.M[level].query("n > 1") # Not the right approach
        
    def add_features(self):
        
        for level in range(1, self.w+1):
            print(f"Adding p, i, and h to {level}-gram model ...")        
            self.M[level]['p'] = self.M[level].n / self.M[level].n.sum()
            self.M[level]['i'] = np.log2(1/self.M[level].p)
            self.M[level]['h'] = self.M[level].p * self.M[level].i
            
        for level in range(2, self.w+1):
            print(f"Adding cp, ci, and ch to {level}-gram model ...")
            group_key = self.widx[:level-1]
            self.M[level]['cp'] = self.M[level].n / self.M[level].groupby(group_key).n.sum()
            self.M[level]['ci'] = np.log2(1 / self.M[level].cp)
            self.M[level]['ch'] = self.M[level].cp * self.M[level].ci
            self.M[level] = self.M[level].sort_index()
                                
    def do_all(self):       
        self.make_index()
        self.make_model()
        self.add_features()
        
    def predict_sentence(self, S):
        pass

# %%
LM = NgramModel(training_corpus, unk_list=training_corpus.UNK)

# %%
# LM.make_index()
# LM.make_model()
# LM.add_features()

# %%
LM.do_all()
# Out:
# Converting tokens to list of sentences ...
# Converting sentences to tokens with special tokens ...
# Replacing rare words with UNK ...
# Creating ngrams from offset lists ...
# Creating 3-gram model ...
# Creating 2-gram model ...
# Creating 1-gram model ...
# Getting lo freqs for level 2
# Getting lo freqs for level 3
# Adding p, i, and h to 1-gram model ...
# Adding p, i, and h to 2-gram model ...
# Adding p, i, and h to 3-gram model ...
# Adding cp, ci, and ch to 2-gram model ...
# Adding cp, ci, and ch to 3-gram model ...

# %% [markdown]
# # Explore

# %%
LM.M[2].xs('her', level=1).sort_values('n', ascending=False).head(30)\
    .sort_values('cp', ascending=True).tail(10).cp.plot.barh();

# %%
LM.M[2].xs('him', level=1).sort_values('n', ascending=False).head(30)\
    .sort_values('cp', ascending=True).tail(10).cp.plot.barh();

# %%
LM.M[2].loc['he'].n.sort_values().tail(10).plot.barh();

# %%
LM.M[3].loc['he'].n.sort_values().tail(10).plot.barh();

# %% [markdown]
# # Precict Sentences

# %% [markdown]
# # Test

# %% [markdown]
# ## Prepare test data

# %% [markdown]
# ### Define list of test sentences

# %%
# Some paragraphs from Austen's _Emma_
test_sentences = """
The event had every promise of happiness for her friend 
Mr Weston was a man of unexceptionable character easy fortune suitable age and pleasant manners
and there was some satisfaction in considering with what self-denying generous friendship she had always wished and promoted the match
but it was a black morning's work for her 
The want of Miss Taylor would be felt every hour of every day 
She recalled her past kindness the kindness the affection of sixteen years 
how she had taught and how she had played with her from five years old 
how she had devoted all her powers to attach and amuse her in health 
and how nursed her through the various illnesses of childhood 
A large debt of gratitude was owing here 
but the intercourse of the last seven years 
the equal footing and perfect unreserve which had soon followed Isabella's marriage 
on their being left to each other was yet a dearer tenderer recollection 
She had been a friend and companion such as few possessed intelligent well-informed useful gentle 
knowing all the ways of the family 
interested in all its concerns 
and peculiarly interested in herself in every pleasure every scheme of hers 
one to whom she could speak every thought as it arose 
and who had such an affection for her as could never find fault 
How was she to bear the change 
It was true that her friend was going only half a mile from them 
but Emma was aware that great must be the difference between a Mrs Weston 
only half a mile from them 
and a Miss Taylor in the house 
and with all her advantages natural and domestic 
she was now in great danger of suffering from intellectual solitude 
She dearly loved her father 
but he was no companion for her 
He could not meet her in conversation rational or playful 
The evil of the actual disparity in their ages
and Mr Woodhouse had not married early
was much increased by his constitution and habits 
for having been a valetudinarian all his life 
without activity of mind or body 
he was a much older man in ways than in years 
and though everywhere beloved for the friendliness of his heart and his amiable temper 
his talents could not have recommended him at any time 
Her sister though comparatively but little removed by matrimony 
being settled in London only sixteen miles off was much beyond her daily reach 
and many a long October and November evening must be struggled through at Hartfield 
before Christmas brought the next visit from Isabella and her husband 
and their little children to fill the house and give her pleasant society again 
""".split('\n')[1:-1]

# %% [markdown]
# ### Convert list to data frame

# %%
TS = pd.DataFrame(dict(sent_str=test_sentences))
TS.index.name = 'sent_num'

# %% [markdown]
# ### Tokenize

# %%
TEST_TOKENS = TS.sent_str.apply(lambda x: pd.Series(x.split())).stack().to_frame('token_str')
TEST_TOKENS.index.names = ['sent_num', 'token_num']
TEST_TOKENS['term_str'] = TEST_TOKENS.token_str.str.lower().str.replace(r'\W+', '', regex=True)

# %%
TEST_TOKENS.head()
# Out:
#                    token_str term_str
# sent_num token_num
# 0        0               The      the
#          1             event    event
#          2               had      had
#          3             every    every
#          4           promise  promise

# %% [markdown]
# ### Convert to Corpus Object

# %%
test_corpus = Corpus(TEST_TOKENS)
test_corpus.extract_vocab()
test_corpus.extract_hapax_data() # No really used ...

# %%
# test_corpus.TOKENS.loc[3]

# %%
# test_corpus.UNK

# %% [markdown]
# ## Generate test data

# %%
LMT = NgramModel(test_corpus, unk_list=training_corpus.UNK)
LMT.make_index()
LMT.make_model()
# Out:
# Converting tokens to list of sentences ...
# Converting sentences to tokens with special tokens ...
# Replacing rare words with UNK ...
# Creating ngrams from offset lists ...
# Creating 3-gram model ...
# Creating 2-gram model ...
# Creating 1-gram model ...
# Getting lo freqs for level 2
# Getting lo freqs for level 3

# %% [markdown]
# ## Compare Models

# %%
class ModelComparator():
    
    def __init__(self, MODEL:NgramModel, TEST:NgramModel, w=3):
        """Compare two models, such as training and test models."""
        
        self.MODEL = MODEL
        self.TEST = TEST
        self.w = w
                    
    def compare(self):
        """Join model to data.""" 

        M = self.MODEL.M[self.w]
        T = self.TEST.M[self.w]

        # We use a right join to keep test data that was not found in training
        self.comp = M.join(T, how='right', rsuffix='_test')

        # Compute differences
        self.ng_intersection = self.comp[~self.comp.n.isna()].index.to_list()
        self.ng_difference = self.comp[self.comp.n.isna()].index.to_list()
        self.hits = round(len(self.ng_intersection) / len(self.comp), 2)

        # Handle OOV words
        unk_key = tuple('<UNK>' for _ in range(self.w))
        unk_add_n = self.comp[self.comp.n.isna()].n_test.sum()
        self.comp.at[unk_key, 'n_test'] += unk_add_n # Update number of UNK items
        self.comp = self.comp[~self.comp.n.isna()] # Remove misses
                        
        # Compute cross-entropy and perplexity of model
        N = self.comp.n_test.sum()
        if self.w > 1: 
            i_col = 'ci'
        else:
            i_col = 'i'
        self.LL = (self.comp[i_col] * self.comp.n_test).sum()
        self.CH = self.LL / N
        self.PP = np.power(2, self.CH)

# %%
C = {}
for i in range(1, 4):
    C[i] = ModelComparator(LM, LMT, i)
    C[i].compare()

# %%
C[3].comp.style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_497ba_row0_col0,#T_497ba_row0_col1,#T_497ba_row0_col7,#T_497ba_row2_col0,#T_497ba_row2_col1,#T_497ba_row2_col3,#T_497ba_row2_col4,#T_497ba_row2_col7,#T_497ba_row3_col0,#T_497ba_row3_col1,#T_497ba_row3_col3,#T_497ba_row3_col4,#T_497ba_row3_col6,#T_497ba_row3_col7,#T_497ba_row4_col7,#T_497ba_row5_col0,#T_497ba_row5_col1,#T_497ba_row5_col7,#T_497ba_row6_col7,#T_497ba_row7_col0,#T_497ba_row7_col1,#T_497ba_row7_col7,#T_497ba_row8_col0,#T_497ba_row8_col1,#T_497ba_row8_col7,#T_497ba_row9_col0,#T_497ba_row9_col1,#T_497ba_row9_col7,#T_497ba_row10_col0,#T_497ba_row10_col1,#T_497ba_row10_col7,#T_497ba_row11_col0,#T_497ba_row11_col1,#T_497ba_row11_col3,#T_497ba_row11_col4,#T_497ba_row11_col7,#T_497ba_row12_col0,#T_497ba_row12_col1,#T_497ba_row12_col7,#T_497ba_row13_col0,#T_497ba_row13_col1,#T_497ba_row13_col3,#T_497ba_row13_col4,#T_497ba_row13_col7,#T_497ba_row14_col0,#T_497ba_row14_col1,#T_497ba_row14_col3,#T_497ba_row14_col4,#T_497ba_row14_col7,#T_497ba_row15_col0,#T_497ba_row15_col1,#T_497ba_row15_col3,#T_497ba_row15_col4,#T_497ba_row15_col7,#T_497ba_row16_col7,#T_497ba_row17_col0,#T_497ba_row17_col1,#T_497ba_row17_col7,#T_497ba_row18_col0,#T_497ba_row18_col1,#T_497ba_row18_col3,#T_497ba_row18_col4,#T_497ba_row18_col7,#T_497ba_row19_col0,#T_497ba_row19_col1,#T_497ba_row19_col3,#T_497ba_row19_col4,#T_497ba_row19_col7,#T_497ba_row20_col0,#T_497ba_row20_col1,#T_497ba_row20_col3,#T_497ba_row20_col7,#T_497ba_row21_col0,#T_497ba_row21_col1,#T_497ba_row21_col3,#T_497ba_row21_col7,#T_497ba_row22_col0,#T_497ba_row22_col1,#T_497ba_row22_col3,#T_497ba_row22_col7,#T_497ba_row23_col0,#T_497ba_row23_col1,#T_497ba_row23_col3,#T_497ba_row23_col4,#T_497ba_row23_col7,#T_497ba_row24_col0,#T_497ba_row24_col1,#T_497ba_row24_col3,#T_497ba_row24_col7,#T_497ba_row25_col0,#T_497ba_row25_col1,#T_497ba_row25_col3,#T_497ba_row25_col4,#T_497ba_row25_col7,#T_497ba_row26_col0,#T_497ba_row26_col1,#T_497ba_row26_col3,#T_497ba_row26_col7,#T_497ba_row27_col0,#T_497ba_row27_col1,#T_497ba_row27_col3,#T_497ba_row27_col7,#T_497ba_row28_col0,#T_497ba_row28_col1,#T_497ba_row28_col3,#T_497ba_row28_col7,#T_497ba_row29_col0,#T_497ba_row29_col1,#T_497ba_row29_col3,#T_497ba_row29_col7,#T_497ba_row30_col0,#T_497ba_row30_col1,#T_497ba_row30_col3,#T_497ba_row30_col7,#T_497ba_row31_col0,#T_497ba_row31_col1,#T_497ba_row31_col3,#T_497ba_row31_col7,#T_497ba_row32_col0,#T_497ba_row32_col1,#T_497ba_row32_col3,#T_497ba_row32_col7,#T_497ba_row33_col0,#T_497ba_row33_col1,#T_497ba_row33_col3,#T_497ba_row33_col7,#T_497ba_row34_col0,#T_497ba_row34_col1,#T_497ba_row34_col7,#T_497ba_row35_col0,#T_497ba_row35_col1,#T_497ba_row35_col3,#T_497ba_row35_col7,#T_497ba_row36_col0,#T_497ba_row36_col1,#T_497ba_row36_col3,#T_497ba_row36_col7,#T_497ba_row37_col0,#T_497ba_row37_col1,#T_497ba_row37_col3,#T_497ba_row37_col7,#T_497ba_row38_col0,#T_497ba_row38_col1,#T_497ba_row38_col7,#T_497ba_row39_col0,#T_497ba_row39_col1,#T_497ba_row39_col3,#T_497ba_row39_col7,#T_497ba_row40_col0,#T_497ba_row40_col1,#T_497ba_row40_col3,#T_497ba_row40_col7,#T_497ba_row41_col0,#T_497ba_row41_col1,#T_497ba_row41_col7,#T_497ba_row42_col0,#T_497ba_row42_col1,#T_497ba_row42_col7,#T_497ba_row43_col0,#T_497ba_row43_col1,#T_497ba_row43_col3,#T_497ba_row43_col4,#T_497ba_row43_col7,#T_497ba_row44_col0,#T_497ba_row44_col1,#T_497ba_row44_col3,#T_497ba_row44_col4,#T_497ba_row44_col7,#T_497ba_row45_col0,#T_497ba_row45_col1,#T_497ba_row45_col3,#T_497ba_row45_col7,#T_497ba_row46_col0,#T_497ba_row46_col1,#T_497ba_row46_col3,#T_497ba_row46_col7,#T_497ba_row47_col0,#T_497ba_row47_col1,#T_497ba_row47_col3,#T_497ba_row47_col7,#T_497ba_row48_col0,#T_497ba_row48_col1,#T_497ba_row48_col3,#T_497ba_row48_col7,#T_497ba_row49_col0,#T_497ba_row49_col1,#T_497ba_row49_col3,#T_497ba_row49_col7,#T_497ba_row50_col0,#T_497ba_row50_col1,#T_497ba_row50_col3,#T_497ba_row50_col7,#T_497ba_row51_col0,#T_497ba_row51_col1,#T_497ba_row51_col3,#T_497ba_row51_col7,#T_497ba_row52_col0,#T_497ba_row52_col1,#T_497ba_row52_col3,#T_497ba_row52_col7,#T_497ba_row53_col0,#T_497ba ...

# %%
for n in range(1, 4): print(n, C[n].LL, C[n].CH, C[n].PP)
# Out:
# 1 4587.980376932609 8.656566748929452 403.5396852239472
# 2 1969.5981872985992 2.124701388671628 4.361128163949524
# 3 673.3424520975109 0.6693264931386789 1.590330365340404

# %% [markdown]
# # Generate Text
#
# We use stupid back-off to account for missing ngrams.

# %%
def generate_text(LM, n=250):
    
    # Get first words
    words = ['<s>']
    next_word = LM.M[2].loc[words[0]].sample(weights='cp').index.values[0]
    words.append(next_word)
    
    # Generate the rest of the text
    for i in range(n):
        try:
            bg = tuple(words[-2:])
            next_word = LM.M[3].loc[bg].sample(weights='cp').index.values[0]
        except: # Fallback if not found
            try:
                ug = words[-1]
                next_word = LM.M[2].loc[ug].sample(weights='cp').index.values[0]
            except: # Fallback if not found            
                next_word = LM.M[1].sample(weights='p').index.values[0][0]
        words.append(next_word)
    
    # Make printable text
    text = ' '.join(words)
    text = re.sub('<s>', '<li>', text)
    text = re.sub(' </s>', '.</li>', text)
    text = re.sub(' s ', "'s ", text)
    text = text.upper()
    display(HTML("<ol style=font-family:monospace;margin:1rem;>"+text+".</ol>"))

# %%
generate_text(LM, n=500)
# Out:
# <ol style=font-family:monospace;margin:1rem;><LI> FOR IN A FINAL SEPARATION.</LI> <LI> HER DAUGHTER.</LI> <LI> I AN T THE LEAST UNEASINESS IN LEAVING THEM BY THE FOLLY OF ROBERT'S OFFENCE WAS UNPARDONABLE BUT LUCY AND NOBODY REMEMBERS TO TALK.</LI> <LI> BUT THAT HE WAS NOW QUITE A BEAU BEFORE HE DIED POOR FELLOW.</LI> <LI> AND SHE WOULD OTHERWISE BE QUITE ALONE.</LI> <LI> SO DO I.</LI> <LI> MARIANNE'S HEART AND ITS SORROWS.</LI> <LI> BUT I SHALL BE A BAD COLD WAS PERSUADED THAT UNDER EVERY POSSIBLE ADVANTAGE.</LI> <LI> THE RESEMBLANCE.</LI> <LI> HE WENT TO BED.</LI> <LI> AND MRS CROFT.</LI> <LI> BUT I NEVER MET BEFORE AND LADY MIDDLETON'S VISITORS.</LI> <LI> NOTHING CAN DO.</LI> <LI> YOU ARE MARRIED ALREADY FOR I HAVE NOT BEEN ABLE TO SET HER OFF TO BE.</LI> <LI> IF YOU SEE.</LI> <LI> OH ELINOR IT IS NOT IN MRS MUSGROVE EXCLAIMED ANNE SHOULD BE EXTREMELY HAPPY.</LI> <LI> TO SAY.</LI> <LI> BUT AT LAST MISS ELLIOT NEVER DANCED.</LI> <LI> A NARRATION IN WHICH MISS STEELE TAKING HER FAMILIARLY BY THE ENTRANCE OF CAPTAIN WENTWORTH UNDER HIS CARE AND BESTOWING ANOTHER GLANCE ON THE ACQUISITION OF TWO SISTERS WAS A PROOF OF HIS HAVING IN EVERY CHANGE OF WEATHER DURING THEIR VISIT SHOULD BEGIN A FEW MONTHS AGO IT WOULD NOT IT.</LI> <LI> NEVER HAD ANY CONFINEMENT BEEN LESS IRKSOME.</LI> <LI> AND WHO WILL BE MORE DELIGHTED WITH THE INHABITANTS HE HAD NOT CONSIDERED THAT MY OPINION OF HIS EYE AND DETERMINED TO GET HER.</LI> <LI> THOUGH I FULLY BELIEVE THAT WITH SUCH A GENEROUS SPIRIT IN THE COUNTRY IN CONSEQUENCE OF THE LATTER WAS PARTICULARLY GRATEFUL.</LI> <LI> HIS SISTERS.</LI> <LI> IT MAY BE FOR HER OPINION AS WELL.</LI> <LI> HE WAS WEARY.</LI> <LI> THEY CAME ALSO FOR A TIME AND CONSCIENCE.</LI> <LI> AND CONTENTING HERSELF WITH SOME HESITATION.</LI> <LI> RATHER SAY YOUR MIND BRANDON I KNOW THAT ONE GREATER OBSTACLE PRESERVED HER IN VAIN.</LI> <LI> AND FOR THE SAKE OF THESE PROPOSALS AND THUS THEY CONTINUED TO TALK TO MEET THE HEARTLESS ELEGANCE OF THE WAY OF GOING YOURSELF INTO MY BEDROOM AND BRINGING ME THE GREATEST PASSION.</LI> <LI> I HAVE DISCHARGED IT IN HER POSSESSION THAN BY HIS PERSONAL CLAIMS AND FELT EQUAL AMAZEMENT.</LI> <LI> SHE WANTED TO CONVINCE HIM WHERE CONVICTION WAS AT STAKE AND MARIANNE SHOULD NOT HAVE KNOWN OR COULD OBLIGE HERSELF TO SEE WHAT IT WAS ENOUGH TO MAKE ROOM FOR HER FOR COUNSEL THEY WOULD ALL BE MADE FOR HIM BUT FOR CAPTAIN BENWICK'S MANNERS.</LI> <LI> IT WAS AND SOMETIMES AT EDWARD WITH COMPASSION AT HER.</LI> <LI> I HAVE FOUND OUT SOMETHING OR A CAP WOULD NOT HEAR OF HIS TIME AT THE TIME.</LI> <LI> WHAT A CHARMING WOMAN QUITE WORTHY TO ADDRESS HERSELF AND THE VANITY OF THE ROOM WITHOUT A SIGH.</LI> <LI> GOOD COMPANY ALWAYS WORTH PRESERVING GOOD COMPANY ALWAYS.</ol>

# %% [markdown]
# # Save

# %%
path_prefix = f"{data_home}/output/austen-combo"

# %%
training_corpus.TOKENS.to_csv(f"{path_prefix}-TOKENS.csv")

# %%
training_corpus.VOCAB.to_csv(f"{path_prefix}-VOCAB.csv")

# %%
training_corpus.hapaxes.to_csv(f"{path_prefix}-HAPAX.csv")

# %%
with open(f"{path_prefix}-UNK.txt", 'w') as outfile:
    outfile.write('\n'.join(training_corpus.UNK))

# %%
for n in range(1, 4):
    LM.M[n].to_csv(f"{path_prefix}-LM{n}.csv")

# %% [markdown]
# # Smoothing
#
# "What do we do with words that are in our vocabulary (they are not unknown words) but appear in a test set in an unseen context (for example they appear after a word they never appeared after in training)?" (Jurafsky and Martin)
#
# How to generalize ngram models when training data lacks certain instances of ngrams.
#
# Note that smoothing is expensive and not very effective.

# %%
UG = LM.M[1].copy()

# %%
N = UG.n.sum()
M = UG.n.count()

# %%
N, M
# Out:
# (232054, 8204)

# %% [markdown]
# ## Unigram Case

# %% [markdown]
# ### LaPlace Smoothing

# %%
UG['laplace_n'] = UG.n + 1

# %%
# UG['laplace_p'] = UG.laplace_n / (N + M)
UG['laplace_p'] = UG.laplace_n / UG.laplace_n.sum()

# %%
UG
# Out:
#             n         p          i         h  laplace_n  laplace_p
# w0
# 1           3  0.000013  16.239139  0.000210          4   0.000017
# 1760        1  0.000004  17.824101  0.000077          2   0.000008
# 1784        1  0.000004  17.824101  0.000077          2   0.000008
# 1785        1  0.000004  17.824101  0.000077          2   0.000008
# 1787        1  0.000004  17.824101  0.000077          2   0.000008
# ...        ..       ...        ...       ...        ...        ...
# youth      22  0.000095  13.364669  0.001267         23   0.000096
# youthful    3  0.000013  16.239139  0.000210          4   0.000017
# zeal        7  0.000030  15.016746  0.000453          8   0.000033
# zealous     4  0.000017  15.824101  0.000273          5   0.000021
# zealously   2  0.000009  16.824101  0.000145          3   0.000012
#
# [8204 rows x 6 columns]

# %% [markdown]
# ### Adjusted Count $c^{*}$ and $p^{*}$

# %%
UG['n_adj'] = (UG.laplace_n) * (N / (N + M))

# %%
UG['p_adj'] = UG.n_adj / N

# %%
UG
# Out:
#             n         p          i         h  laplace_n  laplace_p      n_adj  \
# w0
# 1           3  0.000013  16.239139  0.000210          4   0.000017   3.863413
# 1760        1  0.000004  17.824101  0.000077          2   0.000008   1.931707
# 1784        1  0.000004  17.824101  0.000077          2   0.000008   1.931707
# 1785        1  0.000004  17.824101  0.000077          2   0.000008   1.931707
# 1787        1  0.000004  17.824101  0.000077          2   0.000008   1.931707
# ...        ..       ...        ...       ...        ...        ...        ...
# youth      22  0.000095  13.364669  0.001267         23   0.000096  22.214628
# youthful    3  0.000013  16.239139  0.000210          4   0.000017   3.863413
# zeal        7  0.000030  15.016746  0.000453          8   0.000033   7.726827
# zealous     4  0.000017  15.824101  0.000273          5   0.000021   4.829267
# zealously   2  0.000009  16.824101  0.000145          3   0.000012   2.897560
#
#               p_adj
# w0
# 1          0.000017
# 1760       0.000008
# 1784       0.000008
# 1785       0.000008
# 1787       0.000008
# ...             ...
# youth      0.000096
# youthful   0.000017
# zeal       0.000033
# zealous    0.000021
# zealously  0.000012
#
# [8204 rows x 8 columns]

# %% [markdown]
# ### Discounting

# %%
UG['disc'] = UG.n_adj / UG.n

# %%
UG.disc.sort_values().plot(style='.')
# Out:
# <AxesSubplot:xlabel='w0'>

# %% [markdown]
# ## Bigram Case

# %%
BG = LM.M[2].n.unstack(fill_value=0).stack().to_frame('n')

# %%
len(BG)
# Out:
# 67305616

# %%
BG
# Out:
#                        n
# w0        w1
# 1         1          0.0
#           1760       1.0
#           1784       0.0
#           1785       1.0
#           1787       0.0
# ...                  ...
# zealously youth      0.0
#           youthful   0.0
#           zeal       0.0
#           zealous    0.0
#           zealously  0.0
#
# [67305616 rows x 1 columns]

# %%
BG['p'] = BG.n / BG.n.sum()

# %% [markdown]
# ### LaPlace

# %%
BG['laplace_n'] = BG.n + 1

# %%
# BG

# %%
BG['laplace_p'] = BG.laplace_n / (BG.groupby('w0').laplace_n.sum())

# %%
# BG

# %% [markdown]
# ### Adjusted Count

# %%
BG['n_adj'] = (BG.laplace_n * BG.groupby('w0').n.sum()) / (BG.groupby('w0').laplace_n.sum())

# %%
# BG

# %% [markdown]
# ### Discounting

# %%
BG['disc'] = BG.n_adj / BG.laplace_n

# %% [markdown]
# ### Add K

# %%
k = .5
BG['addk_n'] = BG.n + k
BG['addk_p'] = BG.addk_n / (BG.groupby('w0').addk_n.sum())

# %%
BG
# Out:
#                        n         p  laplace_n  laplace_p     n_adj      disc  \
# w0        w1
# 1         1          0.0  0.000000        1.0   0.000122  0.000366  0.000366
#           1760       1.0  0.000003        2.0   0.000244  0.000731  0.000366
#           1784       0.0  0.000000        1.0   0.000122  0.000366  0.000366
#           1785       1.0  0.000003        2.0   0.000244  0.000731  0.000366
#           1787       0.0  0.000000        1.0   0.000122  0.000366  0.000366
# ...                  ...       ...        ...        ...       ...       ...
# zealously youth      0.0  0.000000        1.0   0.000122  0.000244  0.000244
#           youthful   0.0  0.000000        1.0   0.000122  0.000244  0.000244
#           zeal       0.0  0.000000        1.0   0.000122  0.000244  0.000244
#           zealous    0.0  0.000000        1.0   0.000122  0.000244  0.000244
#           zealously  0.0  0.000000        1.0   0.000122  0.000244  0.000244
#
#                      addk_n    addk_p
# w0        w1
# 1         1             0.5  0.000122
#           1760          1.5  0.000365
#           1784          0.5  0.000122
#           1785          1.5  0.000365
#           1787          0.5  0.000122
# ...                     ...       ...
# zealously youth         0.5  0.000122
#           youthful      0.5  0.000122
#           zeal          0.5  0.000122
#           zealous       0.5  0.000122
#           zealously     0.5  0.000122
#
# [67305616 rows x 8 columns]

# %% [markdown]
# ### Backoff and Interpolation

# %%
# BG.plot.scatter('laplace_p','addk_p')

# %% [markdown]
# # To Do
#
# * Write a Tokenizer object that will work with a variety of formats and i/o options.
# * Write a Corpus object that takes the results of Tokenizer
# * Write a LanguageModel object

# %% [markdown]
# # Experiment

# %%
UG2 = LM.M[1].copy()
UG2.index = [item[0] for item in UG2.index] # Convert index from single item tuple
BG2 = LM.M[2].copy()
TG2 = LM.M[3].copy()

# %%
UG2['bgx'] = BG2.groupby('w1').n.count()\
    .reset_index().rename(columns={'w1':'w0'}).set_index('w0')

# %%
UG2['tgx'] = TG2.groupby('w1').n.count()\
    .reset_index().rename(columns={'w1':'w0'}).set_index('w0')

# %%
UG2.sort_values('bgx', ascending=False)
# Out:
#                   n         p          i         h   bgx   tgx
# </s>          13625  0.058715   4.090132  0.240151  2829  2829
# and            6290  0.027106   5.205257  0.141092  1968  4697
# of             6145  0.026481   5.238904  0.138731  1703  4992
# to             6924  0.029838   5.066711  0.151180  1630  5483
# in             3368  0.014514   6.106425  0.088628  1221  2683
# ...             ...       ...        ...       ...   ...   ...
# publication       1  0.000004  17.824101  0.000077     1     1
# publications      2  0.000009  16.824101  0.000145     1     2
# publicity         1  0.000004  17.824101  0.000077     1     1
# publicly          1  0.000004  17.824101  0.000077     1     1
# joyfully          2  0.000009  16.824101  0.000145     1     2
#
# [8204 rows x 6 columns]

# %%
UG2.sort_values('tgx', ascending=False)
# Out:
#                   n         p          i         h   bgx   tgx
# to             6924  0.029838   5.066711  0.151180  1630  5483
# the            7436  0.032044   4.963790  0.159061  1013  5261
# of             6145  0.026481   5.238904  0.138731  1703  4992
# and            6290  0.027106   5.205257  0.141092  1968  4697
# </s>          13625  0.058715   4.090132  0.240151  2829  2829
# ...             ...       ...        ...       ...   ...   ...
# entrusted         1  0.000004  17.824101  0.000077     1     1
# requisitions      1  0.000004  17.824101  0.000077     1     1
# requited          1  0.000004  17.824101  0.000077     1     1
# rescued           1  0.000004  17.824101  0.000077     1     1
# shudder           1  0.000004  17.824101  0.000077     1     1
#
# [8204 rows x 6 columns]

# %%
UG2['bgxp'] = UG2.bgx / UG2.bgx.sum()
UG2['tgxp'] = UG2.tgx / UG2.tgx.sum()
UG2['bgxh'] = UG2.bgxp * np.log2(1/UG2.bgxp)
UG2['tgxh'] = UG2.tgxp * np.log2(1/UG2.tgxp)

# %%
sns.lmplot(data=UG2, x='p', y='bgxh', aspect=1.5, order=2);

# %%
sns.lmplot(data=UG2, x='p', y='tgxh', aspect=1.5, order=2);
