# %% [markdown]
# # Metadata
#
# ```
# Course:   DS 5001
# Module:   04 HW KEY
# Author:   R.C. Alvarado
# ```

# %% [markdown]
# # Instructions
#
# In this week’s code exercise, you will use NLTK to help tokenize and annotate a small corpus of George Eliot's novels to create an `F3` level digital analytical edition from them.
#
# Using this week's Lab notebook as a guide (`M04_01_Pipeline.ipynb`), which uses the `TextParser` class in the `/lib` directory of the notebook repository, import and combine the novels contained in the directory `/data/gutenberg/eliot-set`.
#
# You should produce the following related dataframes:
#
# * A library `LIB` with the following metadata (and data) about each book:
#   * The `book_id`, matching the first level of the index in the `CORPUS`.
#   * The raw book title will be sufficient, i.e. with title and author combined.
#   * The path of the source file.
#   * The regex used to parse chapter milestones.
#   * The length of the book (number of tokens).
#   * The number of chapters in the book.
# * A an aggregate of all the novels' tokens `CORPUS` with an appropriate `OHCO` index, with following features:
#   * The token string.
#   * The term string.
#   * THe part-of-speech tag inferred by NLTK.
# * A vocabulary `VOCAB` of terms extracted from `CORPUS`, with the following annotation features derived from either NLTK or by using operations presented in the notebook:
#   * Stopwords.
#   * Porter stems.
#   * Maximum POS; i.e. the most frequently associated POS tag for the term using `.idxmax()`. Note that ties are handled by the method.
#   * POS ambiguity expressed a number of POS tags associated with a term's tokens.
#
# Once you have these, use the dataframes to answer the questions below.
#
# **Hints**:
# * You will need to edit the `ohco_pats` config to match the downloaded texts.
# * You may also need to edit the code that reads files from disk and parses their names.
# * In defining the milestone regexes, be sure to include all chapter-level sections.

# %% [markdown]
# # Questions

# %% [markdown]
# ## Q1
#
# What regular expression did you use to chunk _Middlemarch_ into chapters?

# %% [markdown]
# **Answer**: `^(?:PRELUDE|CHAPTER|FINALE)` or something similar.

# %% [markdown]
# ## Q2
#
# What is the title of the book has the most tokens?

# %% [markdown]
# **Answer**: _Middlemarch_.

# %% [markdown]
# ## Q3
#
# How many chapter level chunks are there in this novel?

# %% [markdown]
# **Answer**: 88

# %% [markdown]
# ## Q4
#
# Among the three stemming algorithms -- Porter, Snowball, and Lancaster -- which is the most aggressive, in terms of the number of words associated with each stem?

# %% [markdown]
# **Answer**: Lancaster (1.8 stems/term)

# %% [markdown]
# ## Q5
#
# Using the most aggressive stemmer from the previous question, what is the stem with the most associated terms?
#
# **Answer**: 'cont'

# %% [markdown]
# # Code

# %% [markdown]
# ## Setup

# %%
# data_home = "../labs-repo/data"
# local_lib = "../labs-repo/lib"
data_home = "../../../repo/lessons/data"
local_lib = "../../../repo/lessons/lib"
source_files = f'{data_home}/gutenberg/eliot-set'
data_prefix = 'eliot'

# %%
OHCO = ['book_id', 'chap_num', 'para_num', 'sent_num', 'token_num']

# %%
import pandas as pd
import numpy as np
from glob import glob
import re
import nltk

# %%
import sys
sys.path.append(local_lib)

# %%
from textparser import TextParser

# %% [markdown]
# ## Inspect
#
# Since Project Gutenberg texts vary widely in their markup, we define our chunking patterns by hand.

# %%
roman = '[IVXLCM]+'
caps = "[A-Z';, -]+"
clip_pats = [
    r"\*\*\*\s*START OF",
    r"\*\*\*\s*END OF"
]
# All are 'chap'and 'm'
ohco_pat_list = [
    (6688,  rf"^Chapter\s+{roman}\.\s*$"),
    (507,   rf"^(?:Chapter\s+{roman}|Epilogue)\s*$"),
    (145,   rf"^(?:PRELUDE|BOOK|CHAPTER|FINALE)")
]

# %% [markdown]
# ## Register
#
# We get each file and add to a library `LIB`.

# %%
source_file_list = sorted(glob(f"{source_files}/*.*"))

# %%
source_file_list
# Out:
# ['../../../repo/lessons/data/gutenberg/eliot-set/ELIOT_GEORGE_ADAM_BEDE-pg507.txt',
#  '../../../repo/lessons/data/gutenberg/eliot-set/ELIOT_GEORGE_MIDDLEMARCH-pg145.txt',
#  '../../../repo/lessons/data/gutenberg/eliot-set/ELIOT_GEORGE_THE_MILL_ON_THE_FLOSS-pg6688.txt']

# %%
book_data = []
for source_file_path in source_file_list:
    book_id = int(source_file_path.split('-')[-1].split('.')[0].replace('pg',''))
    book_title = source_file_path.split('/')[-1].split('-')[0].replace('_', ' ')
    book_data.append((book_id, source_file_path, book_title))

# %%
LIB = pd.DataFrame(book_data, columns=['book_id','source_file_path','raw_title'])\
    .set_index('book_id').sort_index()

# %%
LIB
# Out:
#                                           source_file_path  \
# book_id
# 145      ../../../repo/lessons/data/gutenberg/eliot-set...
# 507      ../../../repo/lessons/data/gutenberg/eliot-set...
# 6688     ../../../repo/lessons/data/gutenberg/eliot-set...
#
#                                   raw_title
# book_id
# 145                ELIOT GEORGE MIDDLEMARCH
# 507                  ELIOT GEORGE ADAM BEDE
# 6688     ELIOT GEORGE THE MILL ON THE FLOSS

# %% [markdown]
# ## Tokenize
#
# We tokenize each book and add each `TOKENS` table to a list to be concatenated into a single `CORPUS`.

# %%
books = []
for pat in ohco_pat_list:
    
    book_id, chap_regex = pat
    print("Tokenizing", book_id, LIB.loc[book_id].raw_title)
    ohco_pats = [('chap', chap_regex, 'm')]
    src_file_path = LIB.loc[book_id].source_file_path
    
    text = TextParser(src_file_path, ohco_pats=ohco_pats, clip_pats=clip_pats, use_nltk=True)
    text.verbose = False
    text.strip_hyphens = True
    text.strip_whitespace = True
    text.import_source().parse_tokens();
    text.TOKENS['book_id'] = book_id
    text.TOKENS = text.TOKENS.reset_index().set_index(['book_id'] + text.OHCO)
    
    books.append(text.TOKENS)
# Out:
# Tokenizing 6688 ELIOT GEORGE THE MILL ON THE FLOSS
# line_str chap_str
# Index(['chap_str'], dtype='object')
# Tokenizing 507 ELIOT GEORGE ADAM BEDE
# line_str chap_str
# Index(['chap_str'], dtype='object')
# Tokenizing 145 ELIOT GEORGE MIDDLEMARCH
# line_str chap_str
# Index(['chap_str'], dtype='object')

# %% [markdown]
# ## Create Corpus

# %%
CORPUS = pd.concat(books).sort_index()

# %%
CORPUS.loc[145]
# Out:
#                                            pos_tuple  pos  token_str  \
# chap_id para_num sent_num token_num
# 1       1        0        0                (Who, WP)   WP        Who
#                           1              (that, WDT)  WDT       that
#                           2             (cares, VBZ)  VBZ      cares
#                           3               (much, RB)   RB       much
#                           4                 (to, TO)   TO         to
# ...                                              ...  ...        ...
# 88      24       2        56                (in, IN)   IN         in
#                           57         (unvisited, JJ)   JJ  unvisited
#                           58            (tombs., NN)   NN     tombs.
#         25       0        0                (THE, DT)   DT        THE
#                           1                (END, NN)   NN        END
#
#                                       term_str
# chap_id para_num sent_num token_num
# 1       1        0        0                who
#                           1               that
#                           2              cares
#                           3               much
#                           4                 to
# ...                                        ...
# 88      24       2        56                in
#                           57         unvisited
#                           58             tombs
#         25       0        0                the
#                           1                end
#
# [317844 rows x 4 columns]

# %% [markdown]
# ## Extract some features for `LIB`

# %%
LIB['book_len'] = CORPUS.groupby('book_id').term_str.count()

# %%
LIB['n_chaps'] = CORPUS.reset_index()[['book_id','chap_id']]\
    .drop_duplicates()\
    .groupby('book_id').chap_id.count()

# %%
LIB['chap_regex'] = LIB.index.map(pd.Series({x[0]:x[1] for x in ohco_pat_list}))

# %%
LIB.sort_values('book_len')
# Out:
#                                           source_file_path  \
# book_id
# 6688     ../../../repo/lessons/data/gutenberg/eliot-set...
# 507      ../../../repo/lessons/data/gutenberg/eliot-set...
# 145      ../../../repo/lessons/data/gutenberg/eliot-set...
#
#                                   raw_title  book_len  n_chaps  \
# book_id
# 6688     ELIOT GEORGE THE MILL ON THE FLOSS    207461       58
# 507                  ELIOT GEORGE ADAM BEDE    215405       57
# 145                ELIOT GEORGE MIDDLEMARCH    317805       88
#
#                                     chap_regex
# book_id
# 6688                ^Chapter\s+[IVXLCM]+\.\s*$
# 507      ^(?:Chapter\s+[IVXLCM]+|Epilogue)\s*$
# 145           ^(?:PRELUDE|BOOK|CHAPTER|FINALE)

# %% [markdown]
# ## Exract VOCAB
#
# Extract a vocabulary from the CORPUS as a whole

# %%
# CORPUS[CORPUS.term_str == '']

# %%
CORPUS[CORPUS.term_str == ''].token_str.value_counts()
# Out:
# &      10
# …       3
# );      2
# ),      2
# ):      1
# ;”      1
# (&)     1
# Name: token_str, dtype: int64

# %%
CORPUS = CORPUS[CORPUS.term_str != '']

# %%
VOCAB = CORPUS.term_str.value_counts().to_frame('n').sort_index()
VOCAB.index.name = 'term_str'
VOCAB['n_chars'] = VOCAB.index.str.len()
VOCAB['p'] = VOCAB.n / VOCAB.n.sum()
VOCAB['i'] = -np.log2(VOCAB.p)

# %% [markdown]
# ## Annotate VOCAB

# %%
VOCAB['max_pos'] = CORPUS[['term_str','pos']].value_counts().unstack(fill_value=0).idxmax(1)

# %%
TPM = CORPUS[['term_str','pos']].value_counts().unstack()

# %%
VOCAB['n_pos'] = TPM.count(1)

# %%
VOCAB['cat_pos'] = CORPUS[['term_str','pos']].value_counts().to_frame('n').reset_index()\
    .groupby('term_str').pos.apply(lambda x: set(x))

# %%
VOCAB
# Out:
#           n  n_chars         p          i max_pos  n_pos cat_pos
# term_str
# 1         1        1  0.000001  19.498434      CD      1    {CD}
# 1790      1        4  0.000001  19.498434      CD      1    {CD}
# 1799      2        4  0.000003  18.498434      CD      1    {CD}
# 1801more  1        8  0.000001  19.498434      CD      1    {CD}
# 1807      1        4  0.000001  19.498434      CD      1    {CD}
# ...      ..      ...       ...        ...     ...    ...     ...
# œdipus    2        6  0.000003  18.498434      NN      1    {NN}
# μέγεθος   1        7  0.000001  19.498434     NNP      1   {NNP}
# τι        1        2  0.000001  19.498434     NNP      1   {NNP}
# ἀπέρωτος  1        8  0.000001  19.498434      JJ      1    {JJ}
# ἒρως      1        4  0.000001  19.498434     NNP      1   {NNP}
#
# [26351 rows x 7 columns]

# %% [markdown]
# ## Add Stopwords

# %% [markdown]
# We use NLTK's built in stopword list for English. Note that we can add and subtract from this list, or just create our own list and keep it in our data model.

# %%
sw = pd.DataFrame(nltk.corpus.stopwords.words('english'), columns=['term_str'])
sw = sw.reset_index().set_index('term_str')
sw.columns = ['dummy']
sw.dummy = 1

# %%
VOCAB['stop'] = VOCAB.index.map(sw.dummy)
VOCAB['stop'] = VOCAB['stop'].fillna(0).astype('int')

# %%
VOCAB
# Out:
#           n  n_chars         p          i max_pos  n_pos cat_pos  stop
# term_str
# 1         1        1  0.000001  19.498434      CD      1    {CD}     0
# 1790      1        4  0.000001  19.498434      CD      1    {CD}     0
# 1799      2        4  0.000003  18.498434      CD      1    {CD}     0
# 1801more  1        8  0.000001  19.498434      CD      1    {CD}     0
# 1807      1        4  0.000001  19.498434      CD      1    {CD}     0
# ...      ..      ...       ...        ...     ...    ...     ...   ...
# œdipus    2        6  0.000003  18.498434      NN      1    {NN}     0
# μέγεθος   1        7  0.000001  19.498434     NNP      1   {NNP}     0
# τι        1        2  0.000001  19.498434     NNP      1   {NNP}     0
# ἀπέρωτος  1        8  0.000001  19.498434      JJ      1    {JJ}     0
# ἒρως      1        4  0.000001  19.498434     NNP      1   {NNP}     0
#
# [26351 rows x 8 columns]

# %% [markdown]
# ## Add Stems

# %%
from nltk.stem.porter import PorterStemmer
stemmer1 = PorterStemmer()
VOCAB['stem_porter'] = VOCAB.apply(lambda x: stemmer1.stem(x.name), 1)

from nltk.stem.snowball import SnowballStemmer
stemmer2 = SnowballStemmer("english")
VOCAB['stem_snowball'] = VOCAB.apply(lambda x: stemmer2.stem(x.name), 1)

from nltk.stem.lancaster import LancasterStemmer
stemmer3 = LancasterStemmer()
VOCAB['stem_lancaster'] = VOCAB.apply(lambda x: stemmer3.stem(x.name), 1)

# %%
VOCAB.sample(10)
# Out:
#                   n  n_chars         p          i max_pos  n_pos  \
# term_str
# satirically       2       11  0.000003  18.498434      RB      2
# prepare          11        7  0.000015  16.039003      VB      3
# betrothed         3        9  0.000004  17.913472     VBN      2
# envenomed         1        9  0.000001  19.498434      JJ      1
# poetry           25        6  0.000034  14.854578      NN      3
# communicating     5       13  0.000007  17.176506     VBG      2
# conceit          11        7  0.000015  16.039003      NN      3
# pioneersomebody   1       15  0.000001  19.498434      NN      1
# reminded         12        8  0.000016  15.913472     VBD      2
# warrand           4        7  0.000005  17.498434     VBP      2
#
#                        cat_pos  stop      stem_porter    stem_snowball  \
# term_str
# satirically           {RB, NN}     0            satir            satir
# prepare           {VB, JJ, NN}     0           prepar           prepar
# betrothed            {VBN, JJ}     0          betroth          betroth
# envenomed                 {JJ}     0          envenom          envenom
# poetry           {NNP, VB, NN}     0           poetri           poetri
# communicating        {VBG, NN}     0           commun         communic
# conceit          {JJ, NNS, NN}     0          conceit          conceit
# pioneersomebody           {NN}     0  pioneersomebodi  pioneersomebodi
# reminded            {VBN, VBD}     0           remind           remind
# warrand              {NN, VBP}     0          warrand          warrand
#
#                   stem_lancaster
# term_str
# satirically                satir
# prepare                     prep
# betrothed                betroth
# envenomed                envenom
# poetry                    poetry
# communicating             commun
# conceit                  conceit
# pioneersomebody  pioneersomebody
# reminded                  remind
# warrand                  warrand

# %%
VOCAB[VOCAB.stem_porter != VOCAB.stem_snowball]
# Out:
#                n  n_chars         p          i max_pos  n_pos  \
# term_str
# abjectly       1        8  0.000001  19.498434      RB      1
# abruptly      16        8  0.000022  15.498434      RB      5
# abstractedly   3       12  0.000004  17.913472      NN      2
# abundantly     4       10  0.000005  17.498434      VB      3
# accordingly   11       11  0.000015  16.039003      NN      6
# ...           ..      ...       ...        ...     ...    ...
# yeswellyou     1       10  0.000001  19.498434     NNS      1
# yous           3        4  0.000004  17.913472      NN      2
# zealous       10        7  0.000014  16.176506      JJ      1
# æschylus       2        8  0.000003  18.498434     NNP      2
# œdipus         2        6  0.000003  18.498434      NN      1
#
#                                  cat_pos  stop   stem_porter stem_snowball  \
# term_str
# abjectly                            {RB}     0      abjectli        abject
# abruptly           {VBD, JJ, RP, NN, RB}     0      abruptli        abrupt
# abstractedly                    {RB, NN}     0  abstractedli      abstract
# abundantly                 {VB, RB, NNS}     0    abundantli         abund
# accordingly   {IN, JJ, NN, NNS, NNP, RB}     0   accordingli        accord
# ...                                  ...   ...           ...           ...
# yeswellyou                         {NNS}     0      yeswelly    yeswellyou
# yous                            {RB, NN}     0           you          yous
# zealous                             {JJ}     0        zealou       zealous
# æschylus                       {NNP, NN}     0       æschylu      æschylus
# œdipus                              {NN}     0         œdipu        œdipus
#
#              stem_lancaster
# term_str
# abjectly             abject
# abruptly             abrupt
# abstractedly       abstract
# abundantly            abund
# accordingly          accord
# ...                     ...
# yeswellyou       yeswellyou
# yous                     yo
# zealous                zeal
# æschylus           æschylus
# œdipus                 œdip
#
# [655 rows x 11 columns]

# %% [markdown]
# # Answers

# %% [markdown]
# ## Q1

# %%
ohco_pats[0][1]
# Out:
# '^(?:PRELUDE|BOOK|CHAPTER|FINALE)'

# %% [markdown]
# ## Q2

# %%
LIB.loc[LIB.book_len.idxmax()].raw_title
# Out:
# 'ELIOT GEORGE MIDDLEMARCH'

# %% [markdown]
# ## Q3
#
# How many chapter level chunks are there in this novel?

# %%
LIB.loc[145].n_chaps
# Out:
# 88

# %% [markdown]
# ## Q4
#
# Among the three stemming algorithms -- Porter, Snowball, and Lancaster -- which is the most aggressive, defined as the average number of terms associated with each stem?

# %%
for stem_type in ['porter', 'snowball', 'lancaster']:
    x = VOCAB[f"stem_{stem_type}"].value_counts().mean()
    print(stem_type, round(x,2))
# Out:
# porter 1.5
# snowball 1.53
# lancaster 1.8

# %% [markdown]
# lancaster

# %% [markdown]
# ## Q5
#
# Using the most aggressive stemmer from the previous question, what is the stem with the most associated terms?

# %%
most_aggressive_stem = VOCAB.stem_lancaster.value_counts().head(1).index.values[0]

# %%
most_aggressive_stem
# Out:
# 'cont'

# %%
VOCAB.query(f"stem_lancaster == '{most_aggressive_stem}'")
# Out:
#                 n  n_chars         p          i max_pos  n_pos  \
# term_str
# conceal        12        7  0.000016  15.913472      VB      1
# concealed       4        9  0.000005  17.498434     VBD      3
# concealing      3       10  0.000004  17.913472     VBG      2
# concealment    17       11  0.000023  15.410972      NN      2
# concealments    1       12  0.000001  19.498434     NNS      1
# conceals        1        8  0.000001  19.498434     VBZ      1
# concede         1        7  0.000001  19.498434      VB      1
# conceded        1        8  0.000001  19.498434      JJ      1
# conceding       1        9  0.000001  19.498434     VBG      1
# concentrate     3       11  0.000004  17.913472      VB      1
# concentrated   14       12  0.000019  15.691079     VBN      4
# concentrating   3       13  0.000004  17.913472     VBG      1
# concentration   8       13  0.000011  16.498434      NN      2
# concentric      2       10  0.000003  18.498434      JJ      1
# conciliate      5       10  0.000007  17.176506      VB      1
# conciliated     1       11  0.000001  19.498434     VBN      1
# conciliating    2       12  0.000003  18.498434     VBG      1
# conciliation    2       12  0.000003  18.498434      JJ      2
# conciliatory    2       12  0.000003  18.498434      JJ      1
# concur          5        6  0.000007  17.176506      VB      2
# content        22        7  0.000030  15.039003      JJ      3
# contented      41        9  0.000055  14.140882     VBN      4
# contentedly     2       11  0.000003  18.498434      RB      2
# contentment    19       11  0.000026  15.250507      NN      3
# contents       14        8  0.000019  15.691079     NNS      2
# contrarieties   1       13  0.000001  19.498434     NNS      1
# contrariness    1       12  0.000001  19.498434      NN      1
# contrary       56        8  0.000076  13.691079      NN      2
# contrivance     6       11  0.000008  16.913472      NN      1
# contrivances    7       12  0.000009  16.691079     NNS      2
# contrive        4        8  0.000005  17.498434      VB      2
# contrived       6        9  0.000008  16.913472     VBN      1
# contrives       1        9  0.000001  19.498434      NN      1
# contriving      7       10  0.000009  16.691079     VBG      2
#
#                           cat_pos  stop   stem_porter stem_snowball  \
# term_str
# conceal                      {VB}     0       conceal       conceal
# concealed          {VBN, VBD, JJ}     0       conceal       conceal
# concealing              {VBG, NN}     0       conceal       conceal
# concealment              {JJ, NN}     0       conceal       conceal
# concealments                {NNS}     0       conceal       conceal
# conceals                    {VBZ}     0       conceal       conceal
# concede                      {VB}     0        conced        conced
# conceded                     {JJ}     0        conced        conced
# conceding                   {VBG}     0        conced        conced
# concentrate                  {VB}     0      concentr      concentr
# concentrated   {VBN, VBD, JJ, NN}     0      concentr      concentr
# concentrating               {VBG}     0      concentr      concentr
# concentration            {JJ, NN}     0      concentr      concentr
# concentric                   {JJ}     0      concentr      concentr
# conciliate                   {VB}     0       concili       concili
# conciliated                 {VBN}     0       concili       concili
# conciliating                {VBG}     0       concili       concili
# conciliation             {JJ, NN}     0       concili       concili
# conciliatory                 {JJ}     0  conciliatori  conciliatori
# concur                   {VB, NN}     0        concur        concur
# content              {VB, JJ, NN}     0       content       content
# contented      {VBN, VBD, JJ, NN}     0       content       content
# contentedly              {RB, NN}     0   contentedli       content
# contentment         {VBN, JJ, NN}     0       content       content
# contents                {NNS, NN}     0       content       content
# contrarieties               {NNS}     0   contrarieti   contrarieti
# contrariness                 {NN}     0      contrari      contrari
# contrary                 {JJ, NN}     0      contrari      contrari
# contrivance                  {NN}     0       contriv       contriv
# contrivances            {NNS, NN}     0       contriv       contriv
# contrive                {VB, VBP}     0       contriv       contriv
# contrived                   {VBN}     0       contriv       contriv
# contrives                    {NN}     0       contriv       contriv
# contriving              {VBG, NN}     0       contriv       contriv
#
#               stem_lancaster
# term_str
# conceal                 cont
# concealed               cont
# concealing              cont
# concealment             cont
# concealments            cont
# conceals                cont
# concede                 cont
# conceded                cont
# conceding               cont
# concentrate             cont
# concentrated            cont
# concentrating           cont
# concentration           cont
# concentric              cont
# conciliate              cont
# conciliated             cont
# conciliating            cont
# conciliation            cont
# conciliatory            cont
# concur                  cont
# content                 cont
# contented               cont
# contentedly             cont
# contentment             cont
# contents                cont
# contrarieties           cont
# contrariness            cont
# contrary                cont
# contrivance             cont
# contrivances            cont
# contrive                cont
# contrived               cont
# contrives               cont
# contriving              cont
